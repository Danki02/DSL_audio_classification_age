# %% [markdown]
# ### IMPORT E INSTALL

# %%
# !pip install pydub
# !pip install optuna
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1
# Collecting optuna
#   Downloading optuna-4.2.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.14.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.37)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.8-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.2.0-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.4/383.4 kB 10.1 MB/s eta 0:00:00
# Downloading alembic-1.14.1-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 14.4 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.8-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.0 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.8 alembic-1.14.1 colorlog-6.9.0 optuna-4.2.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
import os
import librosa
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from scipy import signal
import gc
from librosa.effects import split
import csv
from google.colab import files
from sklearn.model_selection import train_test_split
import optuna
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_path = '/content/drive/MyDrive/ProjectDSL/Data/development.csv'
train_audio_path = '/content/drive/MyDrive/ProjectDSL/Data/audios_development'
evaluation_path = '/content/drive/MyDrive/ProjectDSL/Data/evaluation.csv'
eval_audio_path = '/content/drive/MyDrive/ProjectDSL/Data/audios_evaluation'

# %% [markdown]
# # DATA ANALYSES

# %%
# Load datasets
df = pd.read_csv(train_path)
df_eval = pd.read_csv(evaluation_path)

# %%
df.info(),df_eval.info(),df.isnull().sum(),df_eval.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2933 entries, 0 to 2932
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Id                      2933 non-null   int64
#  1   sampling_rate           2933 non-null   int64
#  2   age                     2933 non-null   float64
#  3   gender                  2933 non-null   object
#  4   ethnicity               2933 non-null   object
#  5   mean_pitch              2933 non-null   float64
#  6   max_pitch               2933 non-null   float64
#  7   min_pitch               2933 non-null   float64
#  8   jitter                  2933 non-null   float64
#  9   shimmer                 2933 non-null   float64
#  10  energy                  2933 non-null   float64
#  11  zcr_mean                2933 non-null   float64
#  12  spectral_centroid_mean  2933 non-null   float64
#  13  tempo                   2933 non-null   object
#  14  hnr                     2933 non-null   float64
#  15  num_words               2933 non-null   int64
#  16  num_characters          2933 non-null   int64
#  17  num_pauses              2933 non-null   int64
#  18  silence_duration        2933 non-null   float64
#  19  path                    2933 non-null   object
# dtypes: float64(11), int64(5), object(4)
# memory usage: 458.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 691 entries, 0 to 690
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Id                      691 non-null    int64
#  1   sampling_rate           691 non-null    int64
#  2   gender                  691 non-null    object
#  3   ethnicity               691 non-null    object
#  4   mean_pitch              691 non-null    float64
#  5   max_pitch               691 non-null    float64
#  6   min_pitch               691 non-null    float64
#  7   jitter                  691 non-null    float64
#  8   shimmer                 691 non-null    float64
#  9   energy                  691 non-null    float64
#  10  zcr_mean                691 non-null    float64
#  11  spectral_centroid_mean  691 non-null    float64
#  12  tempo                   691 non-null    object
#  13  hnr                     691 non-null    float64
#  14  num_words               691 non-null    int64
#  15  num_characters          691 non-null    int64
#  16  num_pauses              691 non-null    int64
#  17  silence_duration        691 non-null    float64
#  18  path                    691 non-null    object
# dtypes: float64(10), int64(5), object(4)
# memory usage: 102.7+ KB
# (None,
#  None,
#  Id                        0
#  sampling_rate             0
#  age                       0
#  gender                    0
#  ethnicity                 0
#  mean_pitch                0
#  max_pitch                 0
#  min_pitch                 0
#  jitter                    0
#  shimmer                   0
#  energy                    0
#  zcr_mean                  0
#  spectral_centroid_mean    0
#  tempo                     0
#  hnr                       0
#  num_words                 0
#  num_characters            0
#  num_pauses                0
#  silence_duration          0
#  path                      0
#  dtype: int64,
#  Id                        0
#  sampling_rate             0
#  gender                    0
#  ethnicity                 0
#  mean_pitch                0
#  max_pitch                 0
#  min_pitch                 0
#  jitter                    0
#  shimmer                   0
#  energy                    0
#  zcr_mean                  0
#  spectral_centroid_mean    0
#  tempo                     0
#  hnr                       0
#  num_words                 0
#  num_characters            0
#  num_pauses                0
#  silence_duration          0
#  path                      0
#  dtype: int64)

# %% [markdown]
# There are no null values in the DataFrames. However, there are categorical variables that will be encoded later.

# %% [markdown]
# These plots provide insight into the potential accuracy of the prediction.

# %%
# Calculate the bins and labels for the age ranges without adding a column to the DataFrame
bins = np.arange(5, df["age"].max() + 6, 5)  # Starts from 5, includes all ages up to max + 5
labels = [f"{i}-{i+4}" for i in bins[:-1]]  # Create labels like '5-9', '10-14', etc.

# Create a temporary Series for the age ranges
age_ranges = pd.cut(df["age"], bins=bins, labels=labels, right=False, include_lowest=True)  # Include the lowest value (5)

# Count the number of people in each age range
age_range_counts = age_ranges.value_counts().sort_index()  # Sort by the index (age ranges)

# Create the plot
plt.figure(figsize=(10, 6))
bars = plt.barh(age_range_counts.index, age_range_counts.values, color="steelblue")  # Horizontal bar chart

# Add the absolute counts next to the bars
for bar in bars:
    plt.text(bar.get_width() + 5,
             bar.get_y() + bar.get_height() / 2,
             f"{int(bar.get_width())}",
             va='center', fontsize=10, color='black')

# Labels and title
plt.xlabel("Count")
plt.ylabel("Age Range")

# Adding gridlines for better readability
plt.grid(axis="x", linestyle="-", alpha=0.7)
plt.grid(axis="y", linestyle="-", alpha=0.7)

plt.tight_layout()
plt.show()

# %%
def get_audio_duration(file_path):
    # file audio
    audio, sr = librosa.load(file_path, sr=None)
    # Return the duration in seconds
    return librosa.get_duration(y=audio, sr=sr)

# Apply the function to obtain the duration
def add_audio_duration(df, base_path):
    df['duration'] = df['path'].apply(lambda x: get_audio_duration(os.path.join(base_path, x.split("/")[-1])))
    return df

df = add_audio_duration(df, train_audio_path)

# %%
duration_series = pd.Series(df["duration"])


plt.figure(figsize=(10, 6))
duration_series.plot(kind='hist', bins=20)
plt.xlabel("Duration (seconds)", fontsize=12)
plt.ylabel("Count", fontsize=12)

plt.grid(axis="y", linestyle="-", alpha=0.7)
plt.grid(axis="x", linestyle="-", alpha=0.7)


x_ticks = np.arange(0, int(duration_series.max()) + 1, 5)
plt.xticks(x_ticks)

plt.tight_layout()
plt.show()

# %% [markdown]
# As we can see from the plots, the predictions will likely be more accurate for younger subjects, particularly those in the 20-25 age range. The durations are concentrated around 5 and 25 seconds. There are some durations greater than 60.

# %%
df = pd.read_csv(train_path)
decima_riga = df.iloc[806]  # 807th row (index 806)
filename = decima_riga["path"].split("/")[-1]  # Extract the filename from the path
audio_file = os.path.join(train_audio_path, filename)

# ... (Previous code to load the audio file) ...

try:
    y, sr = librosa.load(audio_file)

    # Calculate Mel Spectrogram
    mels = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=40)
    mels_db = librosa.power_to_db(mels, ref=np.max)

    # Calculate MFCCs
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)

    # Create the figure for the Mel Spectrogram
    plt.figure(figsize=(7, 4))  # Adjust figsize as needed
    librosa.display.specshow(mels_db, sr=sr, x_axis='time', y_axis='mel')
    plt.colorbar(format='%+2.0f dB')

    plt.tight_layout()

    # Create the figure for the MFCCs
    plt.figure(figsize=(7, 4))  # Adjust figsize as needed
    librosa.display.specshow(mfccs, sr=sr, x_axis='time')
    plt.colorbar(format='%+2.0f dB')

    plt.ylabel('Features')
    # Add y-axis labels every 5 MFCCs
    plt.yticks(np.arange(0, mfccs.shape[0], 5), np.arange(1, mfccs.shape[0] + 1, 5))

    plt.tight_layout()

    plt.show()  # Show both figures

except FileNotFoundError:
    print(f"File not found: {audio_file}")
except Exception as e:
    print(f"An error occurred: {e}")

# %% [markdown]
# When plotting the Mel spectrogram and MFCCs, the X and Y axes represent different but complementary information:
#
#
# *   ***Mel Spectrogram***: The X-axis represents time, showing how the audio evolves over time. The Y-axis represents the frequency bands on the Mel scale, which mimics human auditory perception, with narrower bands in lower frequencies and wider bands in higher frequencies.
# *   ***MFCCs***: The X-axis also represents time, while the Y-axis shows the MFCC coefficients, which summarize the spectral characteristics of the audio, highlighting elements such as timbre and sound quality.
#
#
# In both cases, the plots provide a visual representation of how sound evolves over time, with the Mel spectrogram highlighting the spectral distribution and MFCCs condensing the key features into a more compact and targeted representation for tasks like classification.

# %%
y, sr = librosa.load(audio_file, sr=None)

# Identify non-silent segments
non_silent_intervals = librosa.effects.split(y, top_db=25)

# Calculate the total duration of the audio
total_duration = librosa.get_duration(y=y, sr=sr)

# Create the plot
plt.figure(figsize=(12, 6))

# Original plot
librosa.display.waveshow(y, sr=sr)  # Using librosa.display.waveshow for the waveform

plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.grid(True, color='navy', alpha=0.2)  # Background grid

# Highlight silent regions in gray
silent_intervals = []
# Initialize the first silent interval if the audio starts with silence
if non_silent_intervals[0][0] > 0:
    silent_intervals.append([0, non_silent_intervals[0][0]])

# Iterate through the non-silent intervals to find the intermediate silent intervals
for i in range(len(non_silent_intervals) - 1):
    silent_intervals.append([non_silent_intervals[i][1], non_silent_intervals[i + 1][0]])

# Add the last silent interval if the audio ends with silence
if non_silent_intervals[-1][1] < len(y):
    silent_intervals.append([non_silent_intervals[-1][1], len(y)])

# Apply gray shading and red lines to the silent intervals
for start, end in silent_intervals:
    # Gray shading
    plt.axvspan(librosa.samples_to_time(start, sr=sr),
                librosa.samples_to_time(end, sr=sr),
                color='gray', alpha=0.3, zorder=-1)  # zorder to send to background

    # Red lines at the edges
    plt.axvline(librosa.samples_to_time(start, sr=sr), color='red', linestyle='--', linewidth=1)
    plt.axvline(librosa.samples_to_time(end, sr=sr), color='red', linestyle='--', linewidth=1)

plt.axvspan(0, 0, color='gray', alpha=0.3, label="Silenced Parts")
# Display the plots
plt.legend(loc='upper right')  # Change legend location
plt.tight_layout()
plt.show()

# %% [markdown]
# The plot for the audio file 807.wav from the development dataset displays both the original and trimmed waveforms. The trimmed waveform has removed all segments where the amplitude is below the 25 dB threshold set by top_db.
#
#
# *   The ***top_db*** parameter in librosa.effects.trim() sets a decibel threshold for identifying non-silent parts of the audio
# *  ***top_db=25***, any segment that is at least 25 dB quieter than the peak amplitude is considered silent and is removed. This helps eliminate low-volume background noise or silence at the start and end of the audio, keeping only the more prominent sounds. In the plot, you can see the difference between the original audio with all silences and the version with silences removed based on the 25 dB threshold.

# %% [markdown]
# # PREPROCESSING

# %% [markdown]
# ####   PREPROCESSING FUNCTIONS

# %%
import gc  # Garbage collector
import pandas as pd
import numpy as np
import os
import librosa

def extract_audio_features(audio_path):
    try:
        audio_44100, sr_44100 = librosa.load(audio_path, sr=44100)
        non_silent_intervals = librosa.effects.split(audio_44100, top_db=25)  # top_db definisce la soglia per il silenzio
        y_trimmed = np.concatenate([audio_44100[start:end] for start, end in non_silent_intervals])

        time = librosa.times_like(audio_44100, sr=sr_44100)
        duration_trimmed = sum((end - start) for start, end in non_silent_intervals) / sr_44100
        # Mel Spectrogram
        mel_spectrogram = librosa.feature.melspectrogram(y=y_trimmed, sr=sr_44100, n_mels=40)
        log_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)
        features_mel = np.concatenate([
            np.mean(log_spectrogram, axis=1),
            np.std(log_spectrogram, axis=1),
        ])

        delta_features = librosa.feature.delta(log_spectrogram)
        features_speed = np.concatenate([
            np.mean(delta_features, axis=1),
            np.std(delta_features, axis=1),
        ])
        delta_delta_features = librosa.feature.delta(log_spectrogram, order=2)
        features_acceleration = np.concatenate([
            np.mean(delta_delta_features, axis=1),
            np.std(delta_delta_features, axis=1),
        ])

        mfcc = librosa.feature.mfcc(y=audio_44100, sr=sr_44100, n_mfcc=13)
        features_mfcc = np.concatenate([
            np.mean(mfcc, axis=1),
            np.std(mfcc, axis=1),
        ])

        mfcc_speed  = librosa.feature.delta(mfcc)
        features_mfcc_speed = np.concatenate([
            np.mean(mfcc_speed, axis=1),
            np.std(mfcc_speed, axis=1),
        ])
        mfcc_acc = librosa.feature.delta(mfcc, order=2)
        features_mfcc_acceleration = np.concatenate([
            np.mean(mfcc_acc, axis=1),
            np.std(mfcc_acc, axis=1),
        ])
        acf = librosa.autocorrelate(y_trimmed)

        acf_mean = np.mean(acf)
        acf_std = np.std(acf)

        return {
            'mel_features': features_mel,
            'mfcc_features': features_mfcc,
            'speed_features': features_speed,
            'acceleration_features': features_acceleration,
            'mfcc_acc': features_mfcc_acceleration,
            'mfcc_speed':features_mfcc_speed,
            'duration_trimmed': duration_trimmed,
            'acf_mean': acf_mean,
            'acf_std': acf_std

        }

    except Exception as e:
        print(f"Errore durante il processamento di {audio_path}: {e}")
        return None

def create_features_dataframe_in_batches(df, audio_base_path, batch_size):
    calculated_features = []

    def batch_generator(df, batch_size):
        for i in range(0, len(df), batch_size):
            yield df.iloc[i:i + batch_size]

    for batch_df in batch_generator(df, batch_size):
        batch_features = []
        for idx, row in batch_df.iterrows():
            print(f"Sono arrivato alla riga: {row['Id']}")

            # Verifica del percorso
            if 'audios_evaluation' in row['path']:
                audio_path = os.path.join(audio_base_path, row['path'][len('audios_evaluation/'):])
            elif 'audios_development' in row['path']:
                audio_path = os.path.join(audio_base_path, row['path'][len('audios_development/'):])
            else:
                print(f"Percorso non riconosciuto: {row['path']}")
                continue

            # Estrazione delle caratteristiche
            features = extract_audio_features(audio_path)

            if features:
                combined_features = row.to_dict()

                mel_features = features['mel_features']
                half = len(mel_features) // 2
                for i in range(half):
                    combined_features[f'mean_mel_{i+1}'] = mel_features[i]
                    combined_features[f'std_mel_{i+1}'] = mel_features[half + i]

                mfcc_features = features['mfcc_features']
                half = len(mfcc_features) // 2
                for i in range(half):
                    combined_features[f'mean_mfcc_{i+1}'] = mfcc_features[i]
                    combined_features[f'std_mfcc_{i+1}'] = mfcc_features[half + i]

                speed_features = features['speed_features']
                half = len(speed_features) // 2
                for i in range(half):
                    combined_features[f'mean_speed_{i+1}'] = speed_features[i]
                    combined_features[f'std_speed_{i+1}'] = speed_features[half + i]

                acceleration_features = features['acceleration_features']
                half = len(acceleration_features) // 2
                for i in range(half):
                    combined_features[f'mean_acceleration_{i+1}'] = acceleration_features[i]
                    combined_features[f'std_acceleration_{i+1}'] = acceleration_features[half + i]

                mfcc_speed_features = features['mfcc_speed']
                half = len(mfcc_speed_features) // 2
                for i in range(half):
                    combined_features[f'mean_mfcc_speed_{i+1}'] = mfcc_speed_features[i]
                    combined_features[f'std_mfcc_speed{i+1}'] = mfcc_speed_features[half + i]

                mfcc_acc_features = features['mfcc_acc']
                half = len(mfcc_acc_features) // 2
                for i in range(half):
                    combined_features[f'mean_mfcc_acceleration_{i+1}'] = mfcc_acc_features[i]
                    combined_features[f'std_mfcc_acceleration_{i+1}'] = mfcc_acc_features[half + i]

                combined_features['acf_mean'] = features['acf_mean']
                combined_features['acf_std'] = features['acf_std']
                combined_features['duration']= features['duration_trimmed']
                batch_features.append(combined_features)

            del features
            gc.collect()

        calculated_features.extend(batch_features)

        del batch_features
        gc.collect()

    new_df = pd.DataFrame(calculated_features)
    return new_df

# %%
def preprocessing(df, audio_path):
  df['gender'] = df['gender'].replace('famale', 'female')
  label_encoder = LabelEncoder()
  df['tempo'] = df['tempo'].astype(str).str.strip('[]').astype(float)
  df["gender"] = label_encoder.fit_transform(df["gender"])
  df.drop(columns=["ethnicity"], inplace=True)
  final_df = create_features_dataframe_in_batches(df, audio_path, 100)
  final_df.drop(columns=['num_words', 'num_characters', 'num_pauses', "sampling_rate"], inplace=True, errors='ignore')
  return final_df

# %% [markdown]
# #### PREPROCESSING INTERFACE

# %%
df_eval = pd.read_csv(evaluation_path)
final_eval_df = preprocessing(df_eval, eval_audio_path)
csv_path = '/content/drive/MyDrive/Data/eval_Saro_features_trimmed_speed_acc_mfcc_acf.csv'
final_eval_df.to_csv(csv_path, index=False)
# Out:
# Sono arrivato alla riga: 0
# Sono arrivato alla riga: 1
# Sono arrivato alla riga: 2
# Sono arrivato alla riga: 3
# Sono arrivato alla riga: 4
# Sono arrivato alla riga: 5
# Sono arrivato alla riga: 6
# Sono arrivato alla riga: 7
# Sono arrivato alla riga: 8
# Sono arrivato alla riga: 9
# Sono arrivato alla riga: 10
# Sono arrivato alla riga: 11
# Sono arrivato alla riga: 12
# Sono arrivato alla riga: 13
# Sono arrivato alla riga: 14
# Sono arrivato alla riga: 15
# Sono arrivato alla riga: 16
# Sono arrivato alla riga: 17
# Sono arrivato alla riga: 18
# Sono arrivato alla riga: 19
# Sono arrivato alla riga: 20
# Sono arrivato alla riga: 21
# Sono arrivato alla riga: 22
# Sono arrivato alla riga: 23
# Sono arrivato alla riga: 24
# Sono arrivato alla riga: 25
# Sono arrivato alla riga: 26
# Sono arrivato alla riga: 27
# Sono arrivato alla riga: 28
# Sono arrivato alla riga: 29
# Sono arrivato alla riga: 30
# Sono arrivato alla riga: 31
# Sono arrivato alla riga: 32
# Sono arrivato alla riga: 33
# Sono arrivato alla riga: 34
# Sono arrivato alla riga: 35
# Sono arrivato alla riga: 36
# Sono arrivato alla riga: 37
# Sono arrivato alla riga: 38
# Sono arrivato alla riga: 39
# Sono arrivato alla riga: 40
# Sono arrivato alla riga: 41
# Sono arrivato alla riga: 42
# Sono arrivato alla riga: 43
# Sono arrivato alla riga: 44
# Sono arrivato alla riga: 45
# Sono arrivato alla riga: 46
# Sono arrivato alla riga: 47
# Sono arrivato alla riga: 48
# Sono arrivato alla riga: 49
# Sono arrivato alla riga: 50
# Sono arrivato alla riga: 51
# Sono arrivato alla riga: 52
# Sono arrivato alla riga: 53
# Sono arrivato alla riga: 54
# Sono arrivato alla riga: 55
# Sono arrivato alla riga: 56
# Sono arrivato alla riga: 57
# Sono arrivato alla riga: 58
# Sono arrivato alla riga: 59
# Sono arrivato alla riga: 60
# Sono arrivato alla riga: 61
# Sono arrivato alla riga: 62
# Sono arrivato alla riga: 63
# Sono arrivato alla riga: 64
# Sono arrivato alla riga: 65
# Sono arrivato alla riga: 66
# Sono arrivato alla riga: 67
# Sono arrivato alla riga: 68
# Sono arrivato alla riga: 69
# Sono arrivato alla riga: 70
# Sono arrivato alla riga: 71
# Sono arrivato alla riga: 72
# Sono arrivato alla riga: 73
# Sono arrivato alla riga: 74
# Sono arrivato alla riga: 75
# Sono arrivato alla riga: 76
# Sono arrivato alla riga: 77
# Sono arrivato alla riga: 78
# Sono arrivato alla riga: 79
# Sono arrivato alla riga: 80
# Sono arrivato alla riga: 81
# Sono arrivato alla riga: 82
# Sono arrivato alla riga: 83
# Sono arrivato alla riga: 84
# Sono arrivato alla riga: 85
# Sono arrivato alla riga: 86
# Sono arrivato alla riga: 87
# Sono arrivato alla riga: 88
# Sono arrivato alla riga: 89
# Sono arrivato alla riga: 90
# Sono arrivato alla riga: 91
# Sono arrivato alla riga: 92
# Sono arrivato alla riga: 93
# Sono arrivato alla riga: 94
# Sono arrivato alla riga: 95
# Sono arrivato alla riga: 96
# Sono arrivato alla riga: 97
# Sono arrivato alla riga: 98
# Sono arrivato alla riga: 99
# Sono arrivato alla riga: 100
# Sono arrivato alla riga: 101
# Sono arrivato alla riga: 102
# Sono arrivato alla riga: 103
# Sono arrivato alla riga: 104
# Sono arrivato alla riga: 105
# Sono arrivato alla riga: 106
# Sono arrivato alla riga: 107
# Sono arrivato alla riga: 108
# Sono arrivato alla riga: 109
# Sono arrivato alla riga: 110
# Sono arrivato alla riga: 111
# Sono arrivato alla riga: 112
# Sono arrivato alla riga: 113
# Sono arrivato alla riga: 114
# Sono arrivato alla riga: 115
# Sono arrivato alla riga: 116
# Sono arrivato alla riga: 117
# Sono arrivato alla riga: 118
# Sono arrivato alla riga: 119
# Sono arrivato alla riga: 120
# Sono arrivato alla riga: 121
# Sono arrivato alla riga: 122
# Sono arrivato alla riga: 123
# Sono arrivato alla riga: 124
# Sono arrivato alla riga: 125
# Sono arrivato alla riga: 126
# Sono arrivato alla riga: 127
# Sono arrivato alla riga: 128
# Sono arrivato alla riga: 129
# Sono arrivato alla riga: 130
# Sono arrivato alla riga: 131
# Sono arrivato alla riga: 132
# Sono arrivato alla riga: 133
# Sono arrivato alla riga: 134
# Sono arrivato alla riga: 135
# Sono arrivato alla riga: 136
# Sono arrivato alla riga: 137
# Sono arrivato alla riga: 138
# Sono arrivato alla riga: 139
# Sono arrivato alla riga: 140
# Sono arrivato alla riga: 141
# Sono arrivato alla riga: 142
# Sono arrivato alla riga: 143
# Sono arrivato alla riga: 144
# Sono arrivato alla riga: 145
# Sono arrivato alla riga: 146
# Sono arrivato alla riga: 147
# Sono arrivato alla riga: 148
# Sono arrivato alla riga: 149
# Sono arrivato alla riga: 150
# Sono arrivato alla riga: 151
# Sono arrivato alla riga: 152
# Sono arrivato alla riga: 153
# Sono arrivato alla riga: 154
# Sono arrivato alla riga: 155
# Sono arrivato alla riga: 156
# Sono arrivato alla riga: 157
# Sono arrivato alla riga: 158
# Sono arrivato alla riga: 159
# Sono arrivato alla riga: 160
# Sono arrivato alla riga: 161
# Sono arrivato alla riga: 162
# Sono arrivato alla riga: 163
# Sono arrivato alla riga: 164
# Sono arrivato alla riga: 165
# Sono arrivato alla riga: 166
# Sono arrivato alla riga: 167
# Sono arrivato alla riga: 168
# Sono arrivato alla riga: 169
# Sono arrivato alla riga: 170
# Sono arrivato alla riga: 171
# Sono arrivato alla riga: 172
# Sono arrivato alla riga: 173
# Sono arrivato alla riga: 174
# Sono arrivato alla riga: 175
# Sono arrivato alla riga: 176
# Sono arrivato alla riga: 177
# Sono arrivato alla riga: 178
# Sono arrivato alla riga: 179
# Sono arrivato alla riga: 180
# Sono arrivato alla riga: 181
# Sono arrivato alla riga: 182
# Sono arrivato alla riga: 183
# Sono arrivato alla riga: 184
# Sono arrivato alla riga: 185
# Sono arrivato alla riga: 186
# Sono arrivato alla riga: 187
# Sono arrivato alla riga: 188
# Sono arrivato alla riga: 189
# Sono arrivato alla riga: 190
# Sono arrivato alla riga: 191
# Sono arrivato alla riga: 192
# Sono arrivato alla riga: 193
# Sono arrivato alla riga: 194
# Sono arrivato alla riga: 195
# Sono arrivato alla riga: 196
# Sono arrivato alla riga: 197
# Sono arrivato alla riga: 198
# Sono arrivato alla riga: 199
# Sono arrivato alla riga: 200
# Sono arrivato alla riga: 201
# Sono arrivato alla riga: 202
# Sono arrivato alla riga: 203
# Sono arrivato alla riga: 204
# Sono arrivato alla riga: 205
# Sono arrivato alla riga: 206
# Sono arrivato alla riga: 207
# Sono arrivato alla riga: 208
# Sono arrivato alla riga: 209
# Sono arrivato alla riga: 210
# Sono arrivato alla riga: 211
# Sono arrivato alla riga: 212
# Sono arrivato alla riga: 213
# Sono arrivato alla riga: 214
# Sono arrivato alla riga: 215
# Sono arrivato alla riga: 216
# Sono arrivato alla riga: 217
# Sono arrivato alla riga: 218
# Sono arrivato alla riga: 219
# Sono arrivato alla riga: 220
# Sono arrivato alla riga: 221
# Sono arrivato alla riga: 222
# Sono arrivato alla riga: 223
# Sono arrivato alla riga: 224
# Sono arrivato alla riga: 225
# Sono arrivato alla riga: 226
# Sono arrivato alla riga: 227
# Sono arrivato alla riga: 228
# Sono arrivato alla riga: 229
# Sono arrivato alla riga: 230
# Sono arrivato alla riga: 231
# Sono arrivato alla riga: 232
# Sono arrivato alla riga: 233
# Sono arrivato alla riga: 234
# Sono arrivato alla riga: 235
# Sono arrivato alla riga: 236
# Sono arrivato alla riga: 237
# Sono arrivato alla riga: 238
# Sono arrivato alla riga: 239
# Sono arrivato alla riga: 240
# Sono arrivato alla riga: 241
# Sono arrivato alla riga: 242
# Sono arrivato alla riga: 243
# Sono arrivato alla riga: 244
# Sono arrivato alla riga: 245
# Sono arrivato alla riga: 246
# Sono arrivato alla riga: 247
# Sono arrivato alla riga: 248
# Sono arrivato alla riga: 249
# Sono arrivato alla riga: 250
# Sono arrivato alla riga: 251
# Sono arrivato alla riga: 252
# Sono arrivato alla riga: 253
# Sono arrivato alla riga: 254
# Sono arrivato alla riga: 255
# Sono arrivato alla riga: 256
# Sono arrivato alla riga: 257
# Sono arrivato alla riga: 258
# Sono arrivato alla riga: 259
# Sono arrivato alla riga: 260
# Sono arrivato alla riga: 261
# Sono arrivato alla riga: 262
# Sono arrivato alla riga: 263
# Sono arrivato alla riga: 264
# Sono arrivato alla riga: 265
# Sono arrivato alla riga: 266
# Sono arrivato alla riga: 267
# Sono arrivato alla riga: 268
# Sono arrivato alla riga: 269
# Sono arrivato alla riga: 270
# Sono arrivato alla riga: 271
# Sono arrivato alla riga: 272
# Sono arrivato alla riga: 273
# Sono arrivato alla riga: 274
# Sono arrivato alla riga: 275
# Sono arrivato alla riga: 276
# Sono arrivato alla riga: 277
# Sono arrivato alla riga: 278
# Sono arrivato alla riga: 279
# Sono arrivato alla riga: 280
# Sono arrivato alla riga: 281
# Sono arrivato alla riga: 282
# Sono arrivato alla riga: 283
# Sono arrivato alla riga: 284
# Sono arrivato alla riga: 285
# Sono arrivato alla riga: 286
# Sono arrivato alla riga: 287
# Sono arrivato alla riga: 288
# Sono arrivato alla riga: 289
# Sono arrivato alla riga: 290
# Sono arrivato alla riga: 291
# Sono arrivato alla riga: 292
# Sono arrivato alla riga: 293
# Sono arrivato alla riga: 294
# Sono arrivato alla riga: 295
# Sono arrivato alla riga: 296
# Sono arrivato alla riga: 297
# Sono arrivato alla riga: 298
# Sono arrivato alla riga: 299
# Sono arrivato alla riga: 300
# Sono arrivato alla riga: 301
# Sono arrivato alla riga: 302
# Sono arrivato alla riga: 303
# Sono arrivato alla riga: 304
# Sono arrivato alla riga: 305
# Sono arrivato alla riga: 306
# Sono arrivato alla riga: 307
# Sono arrivato alla riga: 308
# Sono arrivato alla riga: 309
# Sono arrivato alla riga: 310
# Sono arrivato alla riga: 311
# Sono arrivato alla riga: 312
# Sono arrivato alla riga: 313
# Sono arrivato alla riga: 314
# Sono arrivato alla riga: 315
# Sono arrivato alla riga: 316
# Sono arrivato alla riga: 317
# Sono arrivato alla riga: 318
# Sono arrivato alla riga: 319
# Sono arrivato alla riga: 320
# Sono arrivato alla riga: 321
# Sono arrivato alla riga: 322
# Sono arrivato alla riga: 323
# Sono arrivato alla riga: 324
# Sono arrivato alla riga: 325
# Sono arrivato alla riga: 326
# Sono arrivato alla riga: 327
# Sono arrivato alla riga: 328
# Sono arrivato alla riga: 329
# Sono arrivato alla riga: 330
# Sono arrivato alla riga: 331
# Sono arrivato alla riga: 332
# Sono arrivato alla riga: 333
# Sono arrivato alla riga: 334
# Sono arrivato alla riga: 335
# Sono arrivato alla riga: 336
# Sono arrivato alla riga: 337
# Sono arrivato alla riga: 338
# Sono arrivato alla riga: 339
# Sono arrivato alla riga: 340
# Sono arrivato alla riga: 341
# Sono arrivato alla riga: 342
# Sono arrivato alla riga: 343
# Sono arrivato alla riga: 344
# Sono arrivato alla riga: 345
# Sono arrivato alla riga: 346
# Sono arrivato alla riga: 347
# Sono arrivato alla riga: 348
# Sono arrivato alla riga: 349
# Sono arrivato alla riga: 350
# Sono arrivato alla riga: 351
# Sono arrivato alla riga: 352
# Sono arrivato alla riga: 353
# Sono arrivato alla riga: 354
# Sono arrivato alla riga: 355
# Sono arrivato alla riga: 356
# Sono arrivato alla riga: 357
# Sono arrivato alla riga: 358
# Sono arrivato alla riga: 359
# Sono arrivato alla riga: 360
# Sono arrivato alla riga: 361
# Sono arrivato alla riga: 362
# Sono arrivato alla riga: 363
# Sono arrivato alla riga: 364
# Sono arrivato alla riga: 365
# Sono arrivato alla riga: 366
# Sono arrivato alla riga: 367
# Sono arrivato alla riga: 368
# Sono arrivato alla riga: 369
# Sono arrivato alla riga: 370
# Sono arrivato alla riga: 371
# Sono arrivato alla riga: 372
# Sono arrivato alla riga: 373
# Sono arrivato alla riga: 374
# Sono arrivato alla riga: 375
# Sono arrivato alla riga: 376
# Sono arrivato alla riga: 377
# Sono arrivato alla riga: 378
# Sono arrivato alla riga: 379
# Sono arrivato alla riga: 380
# Sono arrivato alla riga: 381
# Sono arrivato alla riga: 382
# Sono arrivato alla riga: 383
# Sono arrivato alla riga: 384
# Sono arrivato alla riga: 385
# Sono arrivato alla riga: 386
# Sono arrivato alla riga: 387
# Sono arrivato alla riga: 388
# Sono arrivato alla riga: 389
# Sono arrivato alla riga: 390
# Sono arrivato alla riga: 391
# Sono arrivato alla riga: 392
# Sono arrivato alla riga: 393
# Sono arrivato alla riga: 394
# Sono arrivato alla riga: 395
# Sono arrivato alla riga: 396
# Sono arrivato alla riga: 397
# Sono arrivato alla riga: 398
# Sono arrivato alla riga: 399
# Sono arrivato alla riga: 400
# Sono arrivato alla riga: 401
# Sono arrivato alla riga: 402
# Sono arrivato alla riga: 403
# Sono arrivato alla riga: 404
# Sono arrivato alla riga: 405
# Sono arrivato alla riga: 406
# Sono arrivato alla riga: 407
# Sono arrivato alla riga: 408
# Sono arrivato alla riga: 409
# Sono arrivato alla riga: 410
# Sono arrivato alla riga: 411
# Sono arrivato alla riga: 412
# Sono arrivato alla riga: 413
# Sono arrivato alla riga: 414
# Sono arrivato alla riga: 415
# Sono arrivato alla riga: 416
# Sono arrivato alla riga: 417
# Sono arrivato alla riga: 418
# Sono arrivato alla riga: 419
# Sono arrivato alla riga: 420
# Sono arrivato alla riga: 421
# Sono arrivato alla riga: 422
# Sono arrivato alla riga: 423
# Sono arrivato alla riga: 424
# Sono arrivato alla riga: 425
# Sono arrivato alla riga: 426
# Sono arrivato alla riga: 427
# Sono arrivato alla riga: 428
# Sono arrivato alla riga: 429
# Sono arrivato alla riga: 430
# Sono arrivato alla riga: 431
# Sono arrivato alla riga: 432
# Sono arrivato alla riga: 433
# Sono arrivato alla riga: 434
# Sono arrivato alla riga: 435
# Sono arrivato alla riga: 436
# Sono arrivato alla riga: 437
# Sono arrivato alla riga: 438
# Sono arrivato alla riga: 439
# Sono arrivato alla riga: 440
# Sono arrivato alla riga: 441
# Sono arrivato alla riga: 442
# Sono arrivato alla riga: 443
# Sono arrivato alla riga: 444
# Sono arrivato alla riga: 445
# Sono arrivato alla riga: 446
# Sono arrivato alla riga: 447
# Sono arrivato alla riga: 448
# Sono arrivato alla riga: 449
# Sono arrivato alla riga: 450
# Sono arrivato alla riga: 451
# Sono arrivato alla riga: 452
# Sono arrivato alla riga: 453
# Sono arrivato alla riga: 454
# Sono arrivato alla riga: 455
# Sono arrivato alla riga: 456
# Sono arrivato alla riga: 457
# Sono arrivato alla riga: 458
# Sono arrivato alla riga: 459
# Sono arrivato alla riga: 460
# Sono arrivato alla riga: 461
# Sono arrivato alla riga: 462
# Sono arrivato alla riga: 463
# Sono arrivato alla riga: 464
# Sono arrivato alla riga: 465
# Sono arrivato alla riga: 466
# Sono arrivato alla riga: 467
# Sono arrivato alla riga: 468
# Sono arrivato alla riga: 469
# Sono arrivato alla riga: 470
# Sono arrivato alla riga: 471
# Sono arrivato alla riga: 472
# Sono arrivato alla riga: 473
# Sono arrivato alla riga: 474
# Sono arrivato alla riga: 475
# Sono arrivato alla riga: 476
# Sono arrivato alla riga: 477
# Sono arrivato alla riga: 478
# Sono arrivato alla riga: 479
# Sono arrivato alla riga: 480
# Sono arrivato alla riga: 481
# Sono arrivato alla riga: 482
# Sono arrivato alla riga: 483
# Sono arrivato alla riga: 484
# Sono arrivato alla riga: 485
# Sono arrivato alla riga: 486
# Sono arrivato alla riga: 487
# Sono arrivato alla riga: 488
# Sono arrivato alla riga: 489
# Sono arrivato alla riga: 490
# Sono arrivato alla riga: 491
# Sono arrivato alla riga: 492
# Sono arrivato alla riga: 493
# Sono arrivato alla riga: 494
# Sono arrivato alla riga: 495
# Sono arrivato alla riga: 496
# Sono arrivato alla riga: 497
# Sono arrivato alla riga: 498
# Sono arrivato alla riga: 499
# Sono arrivato alla riga: 500
# Sono arrivato alla riga: 501
# Sono arrivato alla riga: 502
# Sono arrivato alla riga: 503
# Sono arrivato alla riga: 504
# Sono arrivato alla riga: 505
# Sono arrivato alla riga: 506
# Sono arrivato alla riga: 507
# Sono arrivato alla riga: 508
# Sono arrivato alla riga: 509
# Sono arrivato alla riga: 510
# Sono arrivato alla riga: 511
# Sono arrivato alla riga: 512
# Sono arrivato alla riga: 513
# Sono arrivato alla riga: 514
# Sono arrivato alla riga: 515
# Sono arrivato alla riga: 516
# Sono arrivato alla riga: 517
# Sono arrivato alla riga: 518
# Sono arrivato alla riga: 519
# Sono arrivato alla riga: 520
# Sono arrivato alla riga: 521
# Sono arrivato alla riga: 522
# Sono arrivato alla riga: 523
# Sono arrivato alla riga: 524
# Sono arrivato alla riga: 525
# Sono arrivato alla riga: 526
# Sono arrivato alla riga: 527
# Sono arrivato alla riga: 528
# Sono arrivato alla riga: 529
# Sono arrivato alla riga: 530
# Sono arrivato alla riga: 531
# Sono arrivato alla riga: 532
# Sono arrivato alla riga: 533
# Sono arrivato alla riga: 534
# Sono arrivato alla riga: 535
# Sono arrivato alla riga: 536
# Sono arrivato alla riga: 537
# Sono arrivato alla riga: 538
# Sono arrivato alla riga: 539
# Sono arrivato alla riga: 540
# Sono arrivato alla riga: 541
# Sono arrivato alla riga: 542
# Sono arrivato alla riga: 543
# Sono arrivato alla riga: 544
# Sono arrivato alla riga: 545
# Sono arrivato alla riga: 546
# Sono arrivato alla riga: 547
# Sono arrivato alla riga: 548
# Sono arrivato alla riga: 549
# Sono arrivato alla riga: 550
# Sono arrivato alla riga: 551
# Sono arrivato alla riga: 552
# Sono arrivato alla riga: 553
# Sono arrivato alla riga: 554
# Sono arrivato alla riga: 555
# Sono arrivato alla riga: 556
# Sono arrivato alla riga: 557
# Sono arrivato alla riga: 558
# Sono arrivato alla riga: 559
# Sono arrivato alla riga: 560
# Sono arrivato alla riga: 561
# Sono arrivato alla riga: 562
# Sono arrivato alla riga: 563
# Sono arrivato alla riga: 564
# Sono arrivato alla riga: 565
# Sono arrivato alla riga: 566
# Sono arrivato alla riga: 567
# Sono arrivato alla riga: 568
# Sono arrivato alla riga: 569
# Sono arrivato alla riga: 570
# Sono arrivato alla riga: 571
# Sono arrivato alla riga: 572
# Sono arrivato alla riga: 573
# Sono arrivato alla riga: 574
# Sono arrivato alla riga: 575
# Sono arrivato alla riga: 576
# Sono arrivato alla riga: 577
# Sono arrivato alla riga: 578
# Sono arrivato alla riga: 579
# Sono arrivato alla riga: 580
# Sono arrivato alla riga: 581
# Sono arrivato alla riga: 582
# Sono arrivato alla riga: 583
# Sono arrivato alla riga: 584
# Sono arrivato alla riga: 585
# Sono arrivato alla riga: 586
# Sono arrivato alla riga: 587
# Sono arrivato alla riga: 588
# Sono arrivato alla riga: 589
# Sono arrivato alla riga: 590
# Sono arrivato alla riga: 591
# Sono arrivato alla riga: 592
# Sono arrivato alla riga: 593
# Sono arrivato alla riga: 594
# Sono arrivato alla riga: 595
# Sono arrivato alla riga: 596
# Sono arrivato alla riga: 597
# Sono arrivato alla riga: 598
# Sono arrivato alla riga: 599
# Sono arrivato alla riga: 600
# Sono arrivato alla riga: 601
# Sono arrivato alla riga: 602
# Sono arrivato alla riga: 603
# Sono arrivato alla riga: 604
# Sono arrivato alla riga: 605
# Sono arrivato alla riga: 606
# Sono arrivato alla riga: 607
# Sono arrivato alla riga: 608
# Sono arrivato alla riga: 609
# Sono arrivato alla riga: 610
# Sono arrivato alla riga: 611
# Sono arrivato alla riga: 612
# Sono arrivato alla riga: 613
# Sono arrivato alla riga: 614
# Sono arrivato alla riga: 615
# Sono arrivato alla riga: 616
# Sono arrivato alla riga: 617
# Sono arrivato alla riga: 618
# Sono arrivato alla riga: 619
# Sono arrivato alla riga: 620
# Sono arrivato alla riga: 621
# Sono arrivato alla riga: 622
# Sono arrivato alla riga: 623
# Sono arrivato alla riga: 624
# Sono arrivato alla riga: 625
# Sono arrivato alla riga: 626
# Sono arrivato alla riga: 627
# Sono arrivato alla riga: 628
# Sono arrivato alla riga: 629
# Sono arrivato alla riga: 630
# Sono arrivato alla riga: 631
# Sono arrivato alla riga: 632
# Sono arrivato alla riga: 633
# Sono arrivato alla riga: 634
# Sono arrivato alla riga: 635
# Sono arrivato alla riga: 636
# Sono arrivato alla riga: 637
# Sono arrivato alla riga: 638
# Sono arrivato alla riga: 639
# Sono arrivato alla riga: 640
# Sono arrivato alla riga: 641
# Sono arrivato alla riga: 642
# Sono arrivato alla riga: 643
# Sono arrivato alla riga: 644
# Sono arrivato alla riga: 645
# Sono arrivato alla riga: 646
# Sono arrivato alla riga: 647
# Sono arrivato alla riga: 648
# Sono arrivato alla riga: 649
# Sono arrivato alla riga: 650
# Sono arrivato alla riga: 651
# Sono arrivato alla riga: 652
# Sono arrivato alla riga: 653
# Sono arrivato alla riga: 654
# Sono arrivato alla riga: 655
# Sono arrivato alla riga: 656
# Sono arrivato alla riga: 657
# Sono arrivato alla riga: 658
# Sono arrivato alla riga: 659
# Sono arrivato alla riga: 660
# Sono arrivato alla riga: 661
# Sono arrivato alla riga: 662
# Sono arrivato alla riga: 663
# Sono arrivato alla riga: 664
# Sono arrivato alla riga: 665
# Sono arrivato alla riga: 666
# Sono arrivato alla riga: 667
# Sono arrivato alla riga: 668
# Sono arrivato alla riga: 669
# Sono arrivato alla riga: 670
# Sono arrivato alla riga: 671
# Sono arrivato alla riga: 672
# Sono arrivato alla riga: 673
# Sono arrivato alla riga: 674
# Sono arrivato alla riga: 675
# Sono arrivato alla riga: 676
# Sono arrivato alla riga: 677
# Sono arrivato alla riga: 678
# Sono arrivato alla riga: 679
# Sono arrivato alla riga: 680
# Sono arrivato alla riga: 681
# Sono arrivato alla riga: 682
# Sono arrivato alla riga: 683
# Sono arrivato alla riga: 684
# Sono arrivato alla riga: 685
# Sono arrivato alla riga: 686
# Sono arrivato alla riga: 687
# Sono arrivato alla riga: 688
# Sono arrivato alla riga: 689
# Sono arrivato alla riga: 690

# %%
df_train = pd.read_csv(train_path)
final_train_df = preprocessing(df_train, train_audio_path)
csv_path = '/content/drive/MyDrive/Data/train_Saro_features_trimmed_speed_acc_mfcc_acf.csv'
final_train_df.to_csv(csv_path, index=False)
# Out:
# Sono arrivato alla riga: 0
# Sono arrivato alla riga: 1
# Sono arrivato alla riga: 2
# Sono arrivato alla riga: 3
# Sono arrivato alla riga: 4
# Sono arrivato alla riga: 5
# Sono arrivato alla riga: 6
# Sono arrivato alla riga: 7
# Sono arrivato alla riga: 8
# Sono arrivato alla riga: 9
# Sono arrivato alla riga: 10
# Sono arrivato alla riga: 11
# Sono arrivato alla riga: 12
# Sono arrivato alla riga: 13
# Sono arrivato alla riga: 14
# Sono arrivato alla riga: 15
# Sono arrivato alla riga: 16
# Sono arrivato alla riga: 17
# Sono arrivato alla riga: 18
# Sono arrivato alla riga: 19
# Sono arrivato alla riga: 20
# Sono arrivato alla riga: 21
# Sono arrivato alla riga: 22
# Sono arrivato alla riga: 23
# Sono arrivato alla riga: 24
# Sono arrivato alla riga: 25
# Sono arrivato alla riga: 26
# Sono arrivato alla riga: 27
# Sono arrivato alla riga: 28
# Sono arrivato alla riga: 29
# Sono arrivato alla riga: 30
# Sono arrivato alla riga: 31
# Sono arrivato alla riga: 32
# Sono arrivato alla riga: 33
# Sono arrivato alla riga: 34
# Sono arrivato alla riga: 35
# Sono arrivato alla riga: 36
# Sono arrivato alla riga: 37
# Sono arrivato alla riga: 38
# Sono arrivato alla riga: 39
# Sono arrivato alla riga: 40
# Sono arrivato alla riga: 41
# Sono arrivato alla riga: 42
# Sono arrivato alla riga: 43
# Sono arrivato alla riga: 44
# Sono arrivato alla riga: 45
# Sono arrivato alla riga: 46
# Sono arrivato alla riga: 47
# Sono arrivato alla riga: 48
# Sono arrivato alla riga: 49
# Sono arrivato alla riga: 50
# Sono arrivato alla riga: 51
# Sono arrivato alla riga: 52
# Sono arrivato alla riga: 53
# Sono arrivato alla riga: 54
# Sono arrivato alla riga: 55
# Sono arrivato alla riga: 56
# Sono arrivato alla riga: 57
# Sono arrivato alla riga: 58
# Sono arrivato alla riga: 59
# Sono arrivato alla riga: 60
# Sono arrivato alla riga: 61
# Sono arrivato alla riga: 62
# Sono arrivato alla riga: 63
# Sono arrivato alla riga: 64
# Sono arrivato alla riga: 65
# Sono arrivato alla riga: 66
# Sono arrivato alla riga: 67
# Sono arrivato alla riga: 68
# Sono arrivato alla riga: 69
# Sono arrivato alla riga: 70
# Sono arrivato alla riga: 71
# Sono arrivato alla riga: 72
# Sono arrivato alla riga: 73
# Sono arrivato alla riga: 74
# Sono arrivato alla riga: 75
# Sono arrivato alla riga: 76
# Sono arrivato alla riga: 77
# Sono arrivato alla riga: 78
# Sono arrivato alla riga: 79
# Sono arrivato alla riga: 80
# Sono arrivato alla riga: 81
# Sono arrivato alla riga: 82
# Sono arrivato alla riga: 83
# Sono arrivato alla riga: 84
# Sono arrivato alla riga: 85
# Sono arrivato alla riga: 86
# Sono arrivato alla riga: 87
# Sono arrivato alla riga: 88
# Sono arrivato alla riga: 89
# Sono arrivato alla riga: 90
# Sono arrivato alla riga: 91
# Sono arrivato alla riga: 92
# Sono arrivato alla riga: 93
# Sono arrivato alla riga: 94
# Sono arrivato alla riga: 95
# Sono arrivato alla riga: 96
# Sono arrivato alla riga: 97
# Sono arrivato alla riga: 98
# Sono arrivato alla riga: 99
# Sono arrivato alla riga: 100
# Sono arrivato alla riga: 101
# Sono arrivato alla riga: 102
# Sono arrivato alla riga: 103
# Sono arrivato alla riga: 104
# Sono arrivato alla riga: 105
# Sono arrivato alla riga: 106
# Sono arrivato alla riga: 107
# Sono arrivato alla riga: 108
# Sono arrivato alla riga: 109
# Sono arrivato alla riga: 110
# Sono arrivato alla riga: 111
# Sono arrivato alla riga: 112
# Sono arrivato alla riga: 113
# Sono arrivato alla riga: 114
# Sono arrivato alla riga: 115
# Sono arrivato alla riga: 116
# Sono arrivato alla riga: 117
# Sono arrivato alla riga: 118
# Sono arrivato alla riga: 119
# Sono arrivato alla riga: 120
# Sono arrivato alla riga: 121
# Sono arrivato alla riga: 122
# Sono arrivato alla riga: 123
# Sono arrivato alla riga: 124
# Sono arrivato alla riga: 125
# Sono arrivato alla riga: 126
# Sono arrivato alla riga: 127
# Sono arrivato alla riga: 128
# Sono arrivato alla riga: 129
# Sono arrivato alla riga: 130
# Sono arrivato alla riga: 131
# Sono arrivato alla riga: 132
# Sono arrivato alla riga: 133
# Sono arrivato alla riga: 134
# Sono arrivato alla riga: 135
# Sono arrivato alla riga: 136
# Sono arrivato alla riga: 137
# Sono arrivato alla riga: 138
# Sono arrivato alla riga: 139
# Sono arrivato alla riga: 140
# Sono arrivato alla riga: 141
# Sono arrivato alla riga: 142
# Sono arrivato alla riga: 143
# Sono arrivato alla riga: 144
# Sono arrivato alla riga: 145
# Sono arrivato alla riga: 146
# Sono arrivato alla riga: 147
# Sono arrivato alla riga: 148
# Sono arrivato alla riga: 149
# Sono arrivato alla riga: 150
# Sono arrivato alla riga: 151
# Sono arrivato alla riga: 152
# Sono arrivato alla riga: 153
# Sono arrivato alla riga: 154
# Sono arrivato alla riga: 155
# Sono arrivato alla riga: 156
# Sono arrivato alla riga: 157
# Sono arrivato alla riga: 158
# Sono arrivato alla riga: 159
# Sono arrivato alla riga: 160
# Sono arrivato alla riga: 161
# Sono arrivato alla riga: 162
# Sono arrivato alla riga: 163
# Sono arrivato alla riga: 164
# Sono arrivato alla riga: 165
# Sono arrivato alla riga: 166
# Sono arrivato alla riga: 167
# Sono arrivato alla riga: 168
# Sono arrivato alla riga: 169
# Sono arrivato alla riga: 170
# Sono arrivato alla riga: 171
# Sono arrivato alla riga: 172
# Sono arrivato alla riga: 173
# Sono arrivato alla riga: 174
# Sono arrivato alla riga: 175
# Sono arrivato alla riga: 176
# Sono arrivato alla riga: 177
# Sono arrivato alla riga: 178
# Sono arrivato alla riga: 179
# Sono arrivato alla riga: 180
# Sono arrivato alla riga: 181
# Sono arrivato alla riga: 182
# Sono arrivato alla riga: 183
# Sono arrivato alla riga: 184
# Sono arrivato alla riga: 185
# Sono arrivato alla riga: 186
# Sono arrivato alla riga: 187
# Sono arrivato alla riga: 188
# Sono arrivato alla riga: 189
# Sono arrivato alla riga: 190
# Sono arrivato alla riga: 191
# Sono arrivato alla riga: 192
# Sono arrivato alla riga: 193
# Sono arrivato alla riga: 194
# Sono arrivato alla riga: 195
# Sono arrivato alla riga: 196
# Sono arrivato alla riga: 197
# Sono arrivato alla riga: 198
# Sono arrivato alla riga: 199
# Sono arrivato alla riga: 200
# Sono arrivato alla riga: 201
# Sono arrivato alla riga: 202
# Sono arrivato alla riga: 203
# Sono arrivato alla riga: 204
# Sono arrivato alla riga: 205
# Sono arrivato alla riga: 206
# Sono arrivato alla riga: 207
# Sono arrivato alla riga: 208
# Sono arrivato alla riga: 209
# Sono arrivato alla riga: 210
# Sono arrivato alla riga: 211
# Sono arrivato alla riga: 212
# Sono arrivato alla riga: 213
# Sono arrivato alla riga: 214
# Sono arrivato alla riga: 215
# Sono arrivato alla riga: 216
# Sono arrivato alla riga: 217
# Sono arrivato alla riga: 218
# Sono arrivato alla riga: 219
# Sono arrivato alla riga: 220
# Sono arrivato alla riga: 221
# Sono arrivato alla riga: 222
# Sono arrivato alla riga: 223
# Sono arrivato alla riga: 224
# Sono arrivato alla riga: 225
# Sono arrivato alla riga: 226
# Sono arrivato alla riga: 227
# Sono arrivato alla riga: 228
# Sono arrivato alla riga: 229
# Sono arrivato alla riga: 230
# Sono arrivato alla riga: 231
# Sono arrivato alla riga: 232
# Sono arrivato alla riga: 233
# Sono arrivato alla riga: 234
# Sono arrivato alla riga: 235
# Sono arrivato alla riga: 236
# Sono arrivato alla riga: 237
# Sono arrivato alla riga: 238
# Sono arrivato alla riga: 239
# Sono arrivato alla riga: 240
# Sono arrivato alla riga: 241
# Sono arrivato alla riga: 242
# Sono arrivato alla riga: 243
# Sono arrivato alla riga: 244
# Sono arrivato alla riga: 245
# Sono arrivato alla riga: 246
# Sono arrivato alla riga: 247
# Sono arrivato alla riga: 248
# Sono arrivato alla riga: 249
# Sono arrivato alla riga: 250
# Sono arrivato alla riga: 251
# Sono arrivato alla riga: 252
# Sono arrivato alla riga: 253
# Sono arrivato alla riga: 254
# Sono arrivato alla riga: 255
# Sono arrivato alla riga: 256
# Sono arrivato alla riga: 257
# Sono arrivato alla riga: 258
# Sono arrivato alla riga: 259
# Sono arrivato alla riga: 260
# Sono arrivato alla riga: 261
# Sono arrivato alla riga: 262
# Sono arrivato alla riga: 263
# Sono arrivato alla riga: 264
# Sono arrivato alla riga: 265
# Sono arrivato alla riga: 266
# Sono arrivato alla riga: 267
# Sono arrivato alla riga: 268
# Sono arrivato alla riga: 269
# Sono arrivato alla riga: 270
# Sono arrivato alla riga: 271
# Sono arrivato alla riga: 272
# Sono arrivato alla riga: 273
# Sono arrivato alla riga: 274
# Sono arrivato alla riga: 275
# Sono arrivato alla riga: 276
# Sono arrivato alla riga: 277
# Sono arrivato alla riga: 278
# Sono arrivato alla riga: 279
# Sono arrivato alla riga: 280
# Sono arrivato alla riga: 281
# Sono arrivato alla riga: 282
# Sono arrivato alla riga: 283
# Sono arrivato alla riga: 284
# Sono arrivato alla riga: 285
# Sono arrivato alla riga: 286
# Sono arrivato alla riga: 287
# Sono arrivato alla riga: 288
# Sono arrivato alla riga: 289
# Sono arrivato alla riga: 290
# Sono arrivato alla riga: 291
# Sono arrivato alla riga: 292
# Sono arrivato alla riga: 293
# Sono arrivato alla riga: 294
# Sono arrivato alla riga: 295
# Sono arrivato alla riga: 296
# Sono arrivato alla riga: 297
# Sono arrivato alla riga: 298
# Sono arrivato alla riga: 299
# Sono arrivato alla riga: 300
# Sono arrivato alla riga: 301
# Sono arrivato alla riga: 302
# Sono arrivato alla riga: 303
# Sono arrivato alla riga: 304
# Sono arrivato alla riga: 305
# Sono arrivato alla riga: 306
# Sono arrivato alla riga: 307
# Sono arrivato alla riga: 308
# Sono arrivato alla riga: 309
# Sono arrivato alla riga: 310
# Sono arrivato alla riga: 311
# Sono arrivato alla riga: 312
# Sono arrivato alla riga: 313
# Sono arrivato alla riga: 314
# Sono arrivato alla riga: 315
# Sono arrivato alla riga: 316
# Sono arrivato alla riga: 317
# Sono arrivato alla riga: 318
# Sono arrivato alla riga: 319
# Sono arrivato alla riga: 320
# Sono arrivato alla riga: 321
# Sono arrivato alla riga: 322
# Sono arrivato alla riga: 323
# Sono arrivato alla riga: 324
# Sono arrivato alla riga: 325
# Sono arrivato alla riga: 326
# Sono arrivato alla riga: 327
# Sono arrivato alla riga: 328
# Sono arrivato alla riga: 329
# Sono arrivato alla riga: 330
# Sono arrivato alla riga: 331
# Sono arrivato alla riga: 332
# Sono arrivato alla riga: 333
# Sono arrivato alla riga: 334
# Sono arrivato alla riga: 335
# Sono arrivato alla riga: 336
# Sono arrivato alla riga: 337
# Sono arrivato alla riga: 338
# Sono arrivato alla riga: 339
# Sono arrivato alla riga: 340
# Sono arrivato alla riga: 341
# Sono arrivato alla riga: 342
# Sono arrivato alla riga: 343
# Sono arrivato alla riga: 344
# Sono arrivato alla riga: 345
# Sono arrivato alla riga: 346
# Sono arrivato alla riga: 347
# Sono arrivato alla riga: 348
# Sono arrivato alla riga: 349
# Sono arrivato alla riga: 350
# Sono arrivato alla riga: 351
# Sono arrivato alla riga: 352
# Sono arrivato alla riga: 353
# Sono arrivato alla riga: 354
# Sono arrivato alla riga: 355
# Sono arrivato alla riga: 356
# Sono arrivato alla riga: 357
# Sono arrivato alla riga: 358
# Sono arrivato alla riga: 359
# Sono arrivato alla riga: 360
# Sono arrivato alla riga: 361
# Sono arrivato alla riga: 362
# Sono arrivato alla riga: 363
# Sono arrivato alla riga: 364
# Sono arrivato alla riga: 365
# Sono arrivato alla riga: 366
# Sono arrivato alla riga: 367
# Sono arrivato alla riga: 368
# Sono arrivato alla riga: 369
# Sono arrivato alla riga: 370
# Sono arrivato alla riga: 371
# Sono arrivato alla riga: 372
# Sono arrivato alla riga: 373
# Sono arrivato alla riga: 374
# Sono arrivato alla riga: 375
# Sono arrivato alla riga: 376
# Sono arrivato alla riga: 377
# Sono arrivato alla riga: 378
# Sono arrivato alla riga: 379
# Sono arrivato alla riga: 380
# Sono arrivato alla riga: 381
# Sono arrivato alla riga: 382
# Sono arrivato alla riga: 383
# Sono arrivato alla riga: 384
# Sono arrivato alla riga: 385
# Sono arrivato alla riga: 386
# Sono arrivato alla riga: 387
# Sono arrivato alla riga: 388
# Sono arrivato alla riga: 389
# Sono arrivato alla riga: 390
# Sono arrivato alla riga: 391
# Sono arrivato alla riga: 392
# Sono arrivato alla riga: 393
# Sono arrivato alla riga: 394
# Sono arrivato alla riga: 395
# Sono arrivato alla riga: 396
# Sono arrivato alla riga: 397
# Sono arrivato alla riga: 398
# Sono arrivato alla riga: 399
# Sono arrivato alla riga: 400
# Sono arrivato alla riga: 401
# Sono arrivato alla riga: 402
# Sono arrivato alla riga: 403
# Sono arrivato alla riga: 404
# Sono arrivato alla riga: 405
# Sono arrivato alla riga: 406
# Sono arrivato alla riga: 407
# Sono arrivato alla riga: 408
# Sono arrivato alla riga: 409
# Sono arrivato alla riga: 410
# Sono arrivato alla riga: 411
# Sono arrivato alla riga: 412
# Sono arrivato alla riga: 413
# Sono arrivato alla riga: 414
# Sono arrivato alla riga: 415
# Sono arrivato alla riga: 416
# Sono arrivato alla riga: 417
# Sono arrivato alla riga: 418
# Sono arrivato alla riga: 419
# Sono arrivato alla riga: 420
# Sono arrivato alla riga: 421
# Sono arrivato alla riga: 422
# Sono arrivato alla riga: 423
# Sono arrivato alla riga: 424
# Sono arrivato alla riga: 425
# Sono arrivato alla riga: 426
# Sono arrivato alla riga: 427
# Sono arrivato alla riga: 428
# Sono arrivato alla riga: 429
# Sono arrivato alla riga: 430
# Sono arrivato alla riga: 431
# Sono arrivato alla riga: 432
# Sono arrivato alla riga: 433
# Sono arrivato alla riga: 434
# Sono arrivato alla riga: 435
# Sono arrivato alla riga: 436
# Sono arrivato alla riga: 437
# Sono arrivato alla riga: 438
# Sono arrivato alla riga: 439
# Sono arrivato alla riga: 440
# Sono arrivato alla riga: 441
# Sono arrivato alla riga: 442
# Sono arrivato alla riga: 443
# Sono arrivato alla riga: 444
# Sono arrivato alla riga: 445
# Sono arrivato alla riga: 446
# Sono arrivato alla riga: 447
# Sono arrivato alla riga: 448
# Sono arrivato alla riga: 449
# Sono arrivato alla riga: 450
# Sono arrivato alla riga: 451
# Sono arrivato alla riga: 452
# Sono arrivato alla riga: 453
# Sono arrivato alla riga: 454
# Sono arrivato alla riga: 455
# Sono arrivato alla riga: 456
# Sono arrivato alla riga: 457
# Sono arrivato alla riga: 458
# Sono arrivato alla riga: 459
# Sono arrivato alla riga: 460
# Sono arrivato alla riga: 461
# Sono arrivato alla riga: 462
# Sono arrivato alla riga: 463
# Sono arrivato alla riga: 464
# Sono arrivato alla riga: 465
# Sono arrivato alla riga: 466
# Sono arrivato alla riga: 467
# Sono arrivato alla riga: 468
# Sono arrivato alla riga: 469
# Sono arrivato alla riga: 470
# Sono arrivato alla riga: 471
# Sono arrivato alla riga: 472
# Sono arrivato alla riga: 473
# Sono arrivato alla riga: 474
# Sono arrivato alla riga: 475
# Sono arrivato alla riga: 476
# Sono arrivato alla riga: 477
# Sono arrivato alla riga: 478
# Sono arrivato alla riga: 479
# Sono arrivato alla riga: 480
# Sono arrivato alla riga: 481
# Sono arrivato alla riga: 482
# Sono arrivato alla riga: 483
# Sono arrivato alla riga: 484
# Sono arrivato alla riga: 485
# Sono arrivato alla riga: 486
# Sono arrivato alla riga: 487
# Sono arrivato alla riga: 488
# Sono arrivato alla riga: 489
# Sono arrivato alla riga: 490
# Sono arrivato alla riga: 491
# Sono arrivato alla riga: 492
# Sono arrivato alla riga: 493
# Sono arrivato alla riga: 494
# Sono arrivato alla riga: 495
# Sono arrivato alla riga: 496
# Sono arrivato alla riga: 497
# Sono arrivato alla riga: 498
# Sono arrivato alla riga: 499
# Sono arrivato alla riga: 500
# Sono arrivato alla riga: 501
# Sono arrivato alla riga: 502
# Sono arrivato alla riga: 503
# Sono arrivato alla riga: 504
# Sono arrivato alla riga: 505
# Sono arrivato alla riga: 506
# Sono arrivato alla riga: 507
# Sono arrivato alla riga: 508
# Sono arrivato alla riga: 509
# Sono arrivato alla riga: 510
# Sono arrivato alla riga: 511
# Sono arrivato alla riga: 512
# Sono arrivato alla riga: 513
# Sono arrivato alla riga: 514
# Sono arrivato alla riga: 515
# Sono arrivato alla riga: 516
# Sono arrivato alla riga: 517
# Sono arrivato alla riga: 518
# Sono arrivato alla riga: 519
# Sono arrivato alla riga: 520
# Sono arrivato alla riga: 521
# Sono arrivato alla riga: 522
# Sono arrivato alla riga: 523
# Sono arrivato alla riga: 524
# Sono arrivato alla riga: 525
# Sono arrivato alla riga: 526
# Sono arrivato alla riga: 527
# Sono arrivato alla riga: 528
# Sono arrivato alla riga: 529
# Sono arrivato alla riga: 530
# Sono arrivato alla riga: 531
# Sono arrivato alla riga: 532
# Sono arrivato alla riga: 533
# Sono arrivato alla riga: 534
# Sono arrivato alla riga: 535
# Sono arrivato alla riga: 536
# Sono arrivato alla riga: 537
# Sono arrivato alla riga: 538
# Sono arrivato alla riga: 539
# Sono arrivato alla riga: 540
# Sono arrivato alla riga: 541
# Sono arrivato alla riga: 542
# Sono arrivato alla riga: 543
# Sono arrivato alla riga: 544
# Sono arrivato alla riga: 545
# Sono arrivato alla riga: 546
# Sono arrivato alla riga: 547
# Sono arrivato alla riga: 548
# Sono arrivato alla riga: 549
# Sono arrivato alla riga: 550
# Sono arrivato alla riga: 551
# Sono arrivato alla riga: 552
# Sono arrivato alla riga: 553
# Sono arrivato alla riga: 554
# Sono arrivato alla riga: 555
# Sono arrivato alla riga: 556
# Sono arrivato alla riga: 557
# Sono arrivato alla riga: 558
# Sono arrivato alla riga: 559
# Sono arrivato alla riga: 560
# Sono arrivato alla riga: 561
# Sono arrivato alla riga: 562
# Sono arrivato alla riga: 563
# Sono arrivato alla riga: 564
# Sono arrivato alla riga: 565
# Sono arrivato alla riga: 566
# Sono arrivato alla riga: 567
# Sono arrivato alla riga: 568
# Sono arrivato alla riga: 569
# Sono arrivato alla riga: 570
# Sono arrivato alla riga: 571
# Sono arrivato alla riga: 572
# Sono arrivato alla riga: 573
# Sono arrivato alla riga: 574
# Sono arrivato alla riga: 575
# Sono arrivato alla riga: 576
# Sono arrivato alla riga: 577
# Sono arrivato alla riga: 578
# Sono arrivato alla riga: 579
# Sono arrivato alla riga: 580
# Sono arrivato alla riga: 581
# Sono arrivato alla riga: 582
# Sono arrivato alla riga: 583
# Sono arrivato alla riga: 584
# Sono arrivato alla riga: 585
# Sono arrivato alla riga: 586
# Sono arrivato alla riga: 587
# Sono arrivato alla riga: 588
# Sono arrivato alla riga: 589
# Sono arrivato alla riga: 590
# Sono arrivato alla riga: 591
# Sono arrivato alla riga: 592
# Sono arrivato alla riga: 593
# Sono arrivato alla riga: 594
# Sono arrivato alla riga: 595
# Sono arrivato alla riga: 596
# Sono arrivato alla riga: 597
# Sono arrivato alla riga: 598
# Sono arrivato alla riga: 599
# Sono arrivato alla riga: 600
# Sono arrivato alla riga: 601
# Sono arrivato alla riga: 602
# Sono arrivato alla riga: 603
# Sono arrivato alla riga: 604
# Sono arrivato alla riga: 605
# Sono arrivato alla riga: 606
# Sono arrivato alla riga: 607
# Sono arrivato alla riga: 608
# Sono arrivato alla riga: 609
# Sono arrivato alla riga: 610
# Sono arrivato alla riga: 611
# Sono arrivato alla riga: 612
# Sono arrivato alla riga: 613
# Sono arrivato alla riga: 614
# Sono arrivato alla riga: 615
# Sono arrivato alla riga: 616
# Sono arrivato alla riga: 617
# Sono arrivato alla riga: 618
# Sono arrivato alla riga: 619
# Sono arrivato alla riga: 620
# Sono arrivato alla riga: 621
# Sono arrivato alla riga: 622
# Sono arrivato alla riga: 623
# Sono arrivato alla riga: 624
# Sono arrivato alla riga: 625
# Sono arrivato alla riga: 626
# Sono arrivato alla riga: 627
# Sono arrivato alla riga: 628
# Sono arrivato alla riga: 629
# Sono arrivato alla riga: 630
# Sono arrivato alla riga: 631
# Sono arrivato alla riga: 632
# Sono arrivato alla riga: 633
# Sono arrivato alla riga: 634
# Sono arrivato alla riga: 635
# Sono arrivato alla riga: 636
# Sono arrivato alla riga: 637
# Sono arrivato alla riga: 638
# Sono arrivato alla riga: 639
# Sono arrivato alla riga: 640
# Sono arrivato alla riga: 641
# Sono arrivato alla riga: 642
# Sono arrivato alla riga: 643
# Sono arrivato alla riga: 644
# Sono arrivato alla riga: 645
# Sono arrivato alla riga: 646
# Sono arrivato alla riga: 647
# Sono arrivato alla riga: 648
# Sono arrivato alla riga: 649
# Sono arrivato alla riga: 650
# Sono arrivato alla riga: 651
# Sono arrivato alla riga: 652
# Sono arrivato alla riga: 653
# Sono arrivato alla riga: 654
# Sono arrivato alla riga: 655
# Sono arrivato alla riga: 656
# Sono arrivato alla riga: 657
# Sono arrivato alla riga: 658
# Sono arrivato alla riga: 659
# Sono arrivato alla riga: 660
# Sono arrivato alla riga: 661
# Sono arrivato alla riga: 662
# Sono arrivato alla riga: 663
# Sono arrivato alla riga: 664
# Sono arrivato alla riga: 665
# Sono arrivato alla riga: 666
# Sono arrivato alla riga: 667
# Sono arrivato alla riga: 668
# Sono arrivato alla riga: 669
# Sono arrivato alla riga: 670
# Sono arrivato alla riga: 671
# Sono arrivato alla riga: 672
# Sono arrivato alla riga: 673
# Sono arrivato alla riga: 674
# Sono arrivato alla riga: 675
# Sono arrivato alla riga: 676
# Sono arrivato alla riga: 677
# Sono arrivato alla riga: 678
# Sono arrivato alla riga: 679
# Sono arrivato alla riga: 680
# Sono arrivato alla riga: 681
# Sono arrivato alla riga: 682
# Sono arrivato alla riga: 683
# Sono arrivato alla riga: 684
# Sono arrivato alla riga: 685
# Sono arrivato alla riga: 686
# Sono arrivato alla riga: 687
# Sono arrivato alla riga: 688
# Sono arrivato alla riga: 689
# Sono arrivato alla riga: 690
# Sono arrivato alla riga: 691
# Sono arrivato alla riga: 692
# Sono arrivato alla riga: 693
# Sono arrivato alla riga: 694
# Sono arrivato alla riga: 695
# Sono arrivato alla riga: 696
# Sono arrivato alla riga: 697
# Sono arrivato alla riga: 698
# Sono arrivato alla riga: 699
# Sono arrivato alla riga: 700
# Sono arrivato alla riga: 701
# Sono arrivato alla riga: 702
# Sono arrivato alla riga: 703
# Sono arrivato alla riga: 704
# Sono arrivato alla riga: 705
# Sono arrivato alla riga: 706
# Sono arrivato alla riga: 707
# Sono arrivato alla riga: 708
# Sono arrivato alla riga: 709
# Sono arrivato alla riga: 710
# Sono arrivato alla riga: 711
# Sono arrivato alla riga: 712
# Sono arrivato alla riga: 713
# Sono arrivato alla riga: 714
# Sono arrivato alla riga: 715
# Sono arrivato alla riga: 716
# Sono arrivato alla riga: 717
# Sono arrivato alla riga: 718
# Sono arrivato alla riga: 719
# Sono arrivato alla riga: 720
# Sono arrivato alla riga: 721
# Sono arrivato alla riga: 722
# Sono arrivato alla riga: 723
# Sono arrivato alla riga: 724
# Sono arrivato alla riga: 725
# Sono arrivato alla riga: 726
# Sono arrivato alla riga: 727
# Sono arrivato alla riga: 728
# Sono arrivato alla riga: 729
# Sono arrivato alla riga: 730
# Sono arrivato alla riga: 731
# Sono arrivato alla riga: 732
# Sono arrivato alla riga: 733
# Sono arrivato alla riga: 734
# Sono arrivato alla riga: 735
# Sono arrivato alla riga: 736
# Sono arrivato alla riga: 737
# Sono arrivato alla riga: 738
# Sono arrivato alla riga: 739
# Sono arrivato alla riga: 740
# Sono arrivato alla riga: 741
# Sono arrivato alla riga: 742
# Sono arrivato alla riga: 743
# Sono arrivato alla riga: 744
# Sono arrivato alla riga: 745
# Sono arrivato alla riga: 746
# Sono arrivato alla riga: 747
# Sono arrivato alla riga: 748
# Sono arrivato alla riga: 749
# Sono arrivato alla riga: 750
# Sono arrivato alla riga: 751
# Sono arrivato alla riga: 752
# Sono arrivato alla riga: 753
# Sono arrivato alla riga: 754
# Sono arrivato alla riga: 755
# Sono arrivato alla riga: 756
# Sono arrivato alla riga: 757
# Sono arrivato alla riga: 758
# Sono arrivato alla riga: 759
# Sono arrivato alla riga: 760
# Sono arrivato alla riga: 761
# Sono arrivato alla riga: 762
# Sono arrivato alla riga: 763
# Sono arrivato alla riga: 764
# Sono arrivato alla riga: 765
# Sono arrivato alla riga: 766
# Sono arrivato alla riga: 767
# Sono arrivato alla riga: 768
# Sono arrivato alla riga: 769
# Sono arrivato alla riga: 770
# Sono arrivato alla riga: 771
# Sono arrivato alla riga: 772
# Sono arrivato alla riga: 773
# Sono arrivato alla riga: 774
# Sono arrivato alla riga: 775
# Sono arrivato alla riga: 776
# Sono arrivato alla riga: 777
# Sono arrivato alla riga: 778
# Sono arrivato alla riga: 779
# Sono arrivato alla riga: 780
# Sono arrivato alla riga: 781
# Sono arrivato alla riga: 782
# Sono arrivato alla riga: 783
# Sono arrivato alla riga: 784
# Sono arrivato alla riga: 785
# Sono arrivato alla riga: 786
# Sono arrivato alla riga: 787
# Sono arrivato alla riga: 788
# Sono arrivato alla riga: 789
# Sono arrivato alla riga: 790
# Sono arrivato alla riga: 791
# Sono arrivato alla riga: 792
# Sono arrivato alla riga: 793
# Sono arrivato alla riga: 794
# Sono arrivato alla riga: 795
# Sono arrivato alla riga: 796
# Sono arrivato alla riga: 797
# Sono arrivato alla riga: 798
# Sono arrivato alla riga: 799
# Sono arrivato alla riga: 800
# Sono arrivato alla riga: 801
# Sono arrivato alla riga: 802
# Sono arrivato alla riga: 803
# Sono arrivato alla riga: 804
# Sono arrivato alla riga: 805
# Sono arrivato alla riga: 806
# Sono arrivato alla riga: 807
# Sono arrivato alla riga: 808
# Sono arrivato alla riga: 809
# Sono arrivato alla riga: 810
# Sono arrivato alla riga: 811
# Sono arrivato alla riga: 812
# Sono arrivato alla riga: 813
# Sono arrivato alla riga: 814
# Sono arrivato alla riga: 815
# Sono arrivato alla riga: 816
# Sono arrivato alla riga: 817
# Sono arrivato alla riga: 818
# Sono arrivato alla riga: 819
# Sono arrivato alla riga: 820
# Sono arrivato alla riga: 821
# Sono arrivato alla riga: 822
# Sono arrivato alla riga: 823
# Sono arrivato alla riga: 824
# Sono arrivato alla riga: 825
# Sono arrivato alla riga: 826
# Sono arrivato alla riga: 827
# Sono arrivato alla riga: 828
# Sono arrivato alla riga: 829
# Sono arrivato alla riga: 830
# Sono arrivato alla riga: 831
# Sono arrivato alla riga: 832
# Sono arrivato alla riga: 833
# Sono arrivato alla riga: 834
# Sono arrivato alla riga: 835
# Sono arrivato alla riga: 836
# Sono arrivato alla riga: 837
# Sono arrivato alla riga: 838
# Sono arrivato alla riga: 839
# Sono arrivato alla riga: 840
# Sono arrivato alla riga: 841
# Sono arrivato alla riga: 842
# Sono arrivato alla riga: 843
# Sono arrivato alla riga: 844
# Sono arrivato alla riga: 845
# Sono arrivato alla riga: 846
# Sono arrivato alla riga: 847
# Sono arrivato alla riga: 848
# Sono arrivato alla riga: 849
# Sono arrivato alla riga: 850
# Sono arrivato alla riga: 851
# Sono arrivato alla riga: 852
# Sono arrivato alla riga: 853
# Sono arrivato alla riga: 854
# Sono arrivato alla riga: 855
# Sono arrivato alla riga: 856
# Sono arrivato alla riga: 857
# Sono arrivato alla riga: 858
# Sono arrivato alla riga: 859
# Sono arrivato alla riga: 860
# Sono arrivato alla riga: 861
# Sono arrivato alla riga: 862
# Sono arrivato alla riga: 863
# Sono arrivato alla riga: 864
# Sono arrivato alla riga: 865
# Sono arrivato alla riga: 866
# Sono arrivato alla riga: 867
# Sono arrivato alla riga: 868
# Sono arrivato alla riga: 869
# Sono arrivato alla riga: 870
# Sono arrivato alla riga: 871
# Sono arrivato alla riga: 872
# Sono arrivato alla riga: 873
# Sono arrivato alla riga: 874
# Sono arrivato alla riga: 875
# Sono arrivato alla riga: 876
# Sono arrivato alla riga: 877
# Sono arrivato alla riga: 878
# Sono arrivato alla riga: 879
# Sono arrivato alla riga: 880
# Sono arrivato alla riga: 881
# Sono arrivato alla riga: 882
# Sono arrivato alla riga: 883
# Sono arrivato alla riga: 884
# Sono arrivato alla riga: 885
# Sono arrivato alla riga: 886
# Sono arrivato alla riga: 887
# Sono arrivato alla riga: 888
# Sono arrivato alla riga: 889
# Sono arrivato alla riga: 890
# Sono arrivato alla riga: 891
# Sono arrivato alla riga: 892
# Sono arrivato alla riga: 893
# Sono arrivato alla riga: 894
# Sono arrivato alla riga: 895
# Sono arrivato alla riga: 896
# Sono arrivato alla riga: 897
# Sono arrivato alla riga: 898
# Sono arrivato alla riga: 899
# Sono arrivato alla riga: 900
# Sono arrivato alla riga: 901
# Sono arrivato alla riga: 902
# Sono arrivato alla riga: 903
# Sono arrivato alla riga: 904
# Sono arrivato alla riga: 905
# Sono arrivato alla riga: 906
# Sono arrivato alla riga: 907
# Sono arrivato alla riga: 908
# Sono arrivato alla riga: 909
# Sono arrivato alla riga: 910
# Sono arrivato alla riga: 911
# Sono arrivato alla riga: 912
# Sono arrivato alla riga: 913
# Sono arrivato alla riga: 914
# Sono arrivato alla riga: 915
# Sono arrivato alla riga: 916
# Sono arrivato alla riga: 917
# Sono arrivato alla riga: 918
# Sono arrivato alla riga: 919
# Sono arrivato alla riga: 920
# Sono arrivato alla riga: 921
# Sono arrivato alla riga: 922
# Sono arrivato alla riga: 923
# Sono arrivato alla riga: 924
# Sono arrivato alla riga: 925
# Sono arrivato alla riga: 926
# Sono arrivato alla riga: 927
# Sono arrivato alla riga: 928
# Sono arrivato alla riga: 929
# Sono arrivato alla riga: 930
# Sono arrivato alla riga: 931
# Sono arrivato alla riga: 932
# Sono arrivato alla riga: 933
# Sono arrivato alla riga: 934
# Sono arrivato alla riga: 935
# Sono arrivato alla riga: 936
# Sono arrivato alla riga: 937
# Sono arrivato alla riga: 938
# Sono arrivato alla riga: 939
# Sono arrivato alla riga: 940
# Sono arrivato alla riga: 941
# Sono arrivato alla riga: 942
# Sono arrivato alla riga: 943
# Sono arrivato alla riga: 944
# Sono arrivato alla riga: 945
# Sono arrivato alla riga: 946
# Sono arrivato alla riga: 947
# Sono arrivato alla riga: 948
# Sono arrivato alla riga: 949
# Sono arrivato alla riga: 950
# Sono arrivato alla riga: 951
# Sono arrivato alla riga: 952
# Sono arrivato alla riga: 953
# Sono arrivato alla riga: 954
# Sono arrivato alla riga: 955
# Sono arrivato alla riga: 956
# Sono arrivato alla riga: 957
# Sono arrivato alla riga: 958
# Sono arrivato alla riga: 959
# Sono arrivato alla riga: 960
# Sono arrivato alla riga: 961
# Sono arrivato alla riga: 962
# Sono arrivato alla riga: 963
# Sono arrivato alla riga: 964
# Sono arrivato alla riga: 965
# Sono arrivato alla riga: 966
# Sono arrivato alla riga: 967
# Sono arrivato alla riga: 968
# Sono arrivato alla riga: 969
# Sono arrivato alla riga: 970
# Sono arrivato alla riga: 971
# Sono arrivato alla riga: 972
# Sono arrivato alla riga: 973
# Sono arrivato alla riga: 974
# Sono arrivato alla riga: 975
# Sono arrivato alla riga: 976
# Sono arrivato alla riga: 977
# Sono arrivato alla riga: 978
# Sono arrivato alla riga: 979
# Sono arrivato alla riga: 980
# Sono arrivato alla riga: 981
# Sono arrivato alla riga: 982
# Sono arrivato alla riga: 983
# Sono arrivato alla riga: 984
# Sono arrivato alla riga: 985
# Sono arrivato alla riga: 986
# Sono arrivato alla riga: 987
# Sono arrivato alla riga: 988
# Sono arrivato alla riga: 989
# Sono arrivato alla riga: 990
# Sono arrivato alla riga: 991
# Sono arrivato alla riga: 992
# Sono arrivato alla riga: 993
# Sono arrivato alla riga: 994
# Sono arrivato alla riga: 995
# Sono arrivato alla riga: 996
# Sono arrivato alla riga: 997
# Sono arrivato alla riga: 998
# Sono arrivato alla riga: 999
# Sono arrivato alla riga: 1000
# Sono arrivato alla riga: 1001
# Sono arrivato alla riga: 1002
# Sono arrivato alla riga: 1003
# Sono arrivato alla riga: 1004
# Sono arrivato alla riga: 1005
# Sono arrivato alla riga: 1006
# Sono arrivato alla riga: 1007
# Sono arrivato alla riga: 1008
# Sono arrivato alla riga: 1009
# Sono arrivato alla riga: 1010
# Sono arrivato alla riga: 1011
# Sono arrivato alla riga: 1012
# Sono arrivato alla riga: 1013
# Sono arrivato alla riga: 1014
# Sono arrivato alla riga: 1015
# Sono arrivato alla riga: 1016
# Sono arrivato alla riga: 1017
# Sono arrivato alla riga: 1018
# Sono arrivato alla riga: 1019
# Sono arrivato alla riga: 1020
# Sono arrivato alla riga: 1021
# Sono arrivato alla riga: 1022
# Sono arrivato alla riga: 1023
# Sono arrivato alla riga: 1024
# Sono arrivato alla riga: 1025
# Sono arrivato alla riga: 1026
# Sono arrivato alla riga: 1027
# Sono arrivato alla riga: 1028
# Sono arrivato alla riga: 1029
# Sono arrivato alla riga: 1030
# Sono arrivato alla riga: 1031
# Sono arrivato alla riga: 1032
# Sono arrivato alla riga: 1033
# Sono arrivato alla riga: 1034
# Sono arrivato alla riga: 1035
# Sono arrivato alla riga: 1036
# Sono arrivato alla riga: 1037
# Sono arrivato alla riga: 1038
# Sono arrivato alla riga: 1039
# Sono arrivato alla riga: 1040
# Sono arrivato alla riga: 1041
# Sono arrivato alla riga: 1042
# Sono arrivato alla riga: 1043
# Sono arrivato alla riga: 1044
# Sono arrivato alla riga: 1045
# Sono arrivato alla riga: 1046
# Sono arrivato alla riga: 1047
# Sono arrivato alla riga: 1048
# Sono arrivato alla riga: 1049
# Sono arrivato alla riga: 1050
# Sono arrivato alla riga: 1051
# Sono arrivato alla riga: 1052
# Sono arrivato alla riga: 1053
# Sono arrivato alla riga: 1054
# Sono arrivato alla riga: 1055
# Sono arrivato alla riga: 1056
# Sono arrivato alla riga: 1057
# Sono arrivato alla riga: 1058
# Sono arrivato alla riga: 1059
# Sono arrivato alla riga: 1060
# Sono arrivato alla riga: 1061
# Sono arrivato alla riga: 1062
# Sono arrivato alla riga: 1063
# Sono arrivato alla riga: 1064
# Sono arrivato alla riga: 1065
# Sono arrivato alla riga: 1066
# Sono arrivato alla riga: 1067
# Sono arrivato alla riga: 1068
# Sono arrivato alla riga: 1069
# Sono arrivato alla riga: 1070
# Sono arrivato alla riga: 1071
# Sono arrivato alla riga: 1072
# Sono arrivato alla riga: 1073
# Sono arrivato alla riga: 1074
# Sono arrivato alla riga: 1075
# Sono arrivato alla riga: 1076
# Sono arrivato alla riga: 1077
# Sono arrivato alla riga: 1078
# Sono arrivato alla riga: 1079
# Sono arrivato alla riga: 1080
# Sono arrivato alla riga: 1081
# Sono arrivato alla riga: 1082
# Sono arrivato alla riga: 1083
# Sono arrivato alla riga: 1084
# Sono arrivato alla riga: 1085
# Sono arrivato alla riga: 1086
# Sono arrivato alla riga: 1087
# Sono arrivato alla riga: 1088
# Sono arrivato alla riga: 1089
# Sono arrivato alla riga: 1090
# Sono arrivato alla riga: 1091
# Sono arrivato alla riga: 1092
# Sono arrivato alla riga: 1093
# Sono arrivato alla riga: 1094
# Sono arrivato alla riga: 1095
# Sono arrivato alla riga: 1096
# Sono arrivato alla riga: 1097
# Sono arrivato alla riga: 1098
# Sono arrivato alla riga: 1099
# Sono arrivato alla riga: 1100
# Sono arrivato alla riga: 1101
# Sono arrivato alla riga: 1102
# Sono arrivato alla riga: 1103
# Sono arrivato alla riga: 1104
# Sono arrivato alla riga: 1105
# Sono arrivato alla riga: 1106
# Sono arrivato alla riga: 1107
# Sono arrivato alla riga: 1108
# Sono arrivato alla riga: 1109
# Sono arrivato alla riga: 1110
# Sono arrivato alla riga: 1111
# Sono arrivato alla riga: 1112
# Sono arrivato alla riga: 1113
# Sono arrivato alla riga: 1114
# Sono arrivato alla riga: 1115
# Sono arrivato alla riga: 1116
# Sono arrivato alla riga: 1117
# Sono arrivato alla riga: 1118
# Sono arrivato alla riga: 1119
# Sono arrivato alla riga: 1120
# Sono arrivato alla riga: 1121
# Sono arrivato alla riga: 1122
# Sono arrivato alla riga: 1123
# Sono arrivato alla riga: 1124
# Sono arrivato alla riga: 1125
# Sono arrivato alla riga: 1126
# Sono arrivato alla riga: 1127
# Sono arrivato alla riga: 1128
# Sono arrivato alla riga: 1129
# Sono arrivato alla riga: 1130
# Sono arrivato alla riga: 1131
# Sono arrivato alla riga: 1132
# Sono arrivato alla riga: 1133
# Sono arrivato alla riga: 1134
# Sono arrivato alla riga: 1135
# Sono arrivato alla riga: 1136
# Sono arrivato alla riga: 1137
# Sono arrivato alla riga: 1138
# Sono arrivato alla riga: 1139
# Sono arrivato alla riga: 1140
# Sono arrivato alla riga: 1141
# Sono arrivato alla riga: 1142
# Sono arrivato alla riga: 1143
# Sono arrivato alla riga: 1144
# Sono arrivato alla riga: 1145
# Sono arrivato alla riga: 1146
# Sono arrivato alla riga: 1147
# Sono arrivato alla riga: 1148
# Sono arrivato alla riga: 1149
# Sono arrivato alla riga: 1150
# Sono arrivato alla riga: 1151
# Sono arrivato alla riga: 1152
# Sono arrivato alla riga: 1153
# Sono arrivato alla riga: 1154
# Sono arrivato alla riga: 1155
# Sono arrivato alla riga: 1156
# Sono arrivato alla riga: 1157
# Sono arrivato alla riga: 1158
# Sono arrivato alla riga: 1159
# Sono arrivato alla riga: 1160
# Sono arrivato alla riga: 1161
# Sono arrivato alla riga: 1162
# Sono arrivato alla riga: 1163
# Sono arrivato alla riga: 1164
# Sono arrivato alla riga: 1165
# Sono arrivato alla riga: 1166
# Sono arrivato alla riga: 1167
# Sono arrivato alla riga: 1168
# Sono arrivato alla riga: 1169
# Sono arrivato alla riga: 1170
# Sono arrivato alla riga: 1171
# Sono arrivato alla riga: 1172
# Sono arrivato alla riga: 1173
# Sono arrivato alla riga: 1174
# Sono arrivato alla riga: 1175
# Sono arrivato alla riga: 1176
# Sono arrivato alla riga: 1177
# Sono arrivato alla riga: 1178
# Sono arrivato alla riga: 1179
# Sono arrivato alla riga: 1180
# Sono arrivato alla riga: 1181
# Sono arrivato alla riga: 1182
# Sono arrivato alla riga: 1183
# Sono arrivato alla riga: 1184
# Sono arrivato alla riga: 1185
# Sono arrivato alla riga: 1186
# Sono arrivato alla riga: 1187
# Sono arrivato alla riga: 1188
# Sono arrivato alla riga: 1189
# Sono arrivato alla riga: 1190
# Sono arrivato alla riga: 1191
# Sono arrivato alla riga: 1192
# Sono arrivato alla riga: 1193
# Sono arrivato alla riga: 1194
# Sono arrivato alla riga: 1195
# Sono arrivato alla riga: 1196
# Sono arrivato alla riga: 1197
# Sono arrivato alla riga: 1198
# Sono arrivato alla riga: 1199
# Sono arrivato alla riga: 1200
# Sono arrivato alla riga: 1201
# Sono arrivato alla riga: 1202
# Sono arrivato alla riga: 1203
# Sono arrivato alla riga: 1204
# Sono arrivato alla riga: 1205
# Sono arrivato alla riga: 1206
# Sono arrivato alla riga: 1207
# Sono arrivato alla riga: 1208
# Sono arrivato alla riga: 1209
# Sono arrivato alla riga: 1210
# Sono arrivato alla riga: 1211
# Sono arrivato alla riga: 1212
# Sono arrivato alla riga: 1213
# Sono arrivato alla riga: 1214
# Sono arrivato alla riga: 1215
# Sono arrivato alla riga: 1216
# Sono arrivato alla riga: 1217
# Sono arrivato alla riga: 1218
# Sono arrivato alla riga: 1219
# Sono arrivato alla riga: 1220
# Sono arrivato alla riga: 1221
# Sono arrivato alla riga: 1222
# Sono arrivato alla riga: 1223
# Sono arrivato alla riga: 1224
# Sono arrivato alla riga: 1225
# Sono arrivato alla riga: 1226
# Sono arrivato alla riga: 1227
# Sono arrivato alla riga: 1228
# Sono arrivato alla riga: 1229
# Sono arrivato alla riga: 1230
# Sono arrivato alla riga: 1231
# Sono arrivato alla riga: 1232
# Sono arrivato alla riga: 1233
# Sono arrivato alla riga: 1234
# Sono arrivato alla riga: 1235
# Sono arrivato alla riga: 1236
# Sono arrivato alla riga: 1237
# Sono arrivato alla riga: 1238
# Sono arrivato alla riga: 1239
# Sono arrivato alla riga: 1240
# Sono arrivato alla riga: 1241
# Sono arrivato alla riga: 1242
# Sono arrivato alla riga: 1243
# Sono arrivato alla riga: 1244
# Sono arrivato alla riga: 1245
# Sono arrivato alla riga: 1246
# Sono arrivato alla riga: 1247
# Sono arrivato alla riga: 1248
# Sono arrivato alla riga: 1249
# Sono arrivato alla riga: 1250
# Sono arrivato alla riga: 1251
# Sono arrivato alla riga: 1252
# Sono arrivato alla riga: 1253
# Sono arrivato alla riga: 1254
# Sono arrivato alla riga: 1255
# Sono arrivato alla riga: 1256
# Sono arrivato alla riga: 1257
# Sono arrivato alla riga: 1258
# Sono arrivato alla riga: 1259
# Sono arrivato alla riga: 1260
# Sono arrivato alla riga: 1261
# Sono arrivato alla riga: 1262
# Sono arrivato alla riga: 1263
# Sono arrivato alla riga: 1264
# Sono arrivato alla riga: 1265
# Sono arrivato alla riga: 1266
# Sono arrivato alla riga: 1267
# Sono arrivato alla riga: 1268
# Sono arrivato alla riga: 1269
# Sono arrivato alla riga: 1270
# Sono arrivato alla riga: 1271
# Sono arrivato alla riga: 1272
# Sono arrivato alla riga: 1273
# Sono arrivato alla riga: 1274
# Sono arrivato alla riga: 1275
# Sono arrivato alla riga: 1276
# Sono arrivato alla riga: 1277
# Sono arrivato alla riga: 1278
# Sono arrivato alla riga: 1279
# Sono arrivato alla riga: 1280
# Sono arrivato alla riga: 1281
# Sono arrivato alla riga: 1282
# Sono arrivato alla riga: 1283
# Sono arrivato alla riga: 1284
# Sono arrivato alla riga: 1285
# Sono arrivato alla riga: 1286
# Sono arrivato alla riga: 1287
# Sono arrivato alla riga: 1288
# Sono arrivato alla riga: 1289
# Sono arrivato alla riga: 1290
# Sono arrivato alla riga: 1291
# Sono arrivato alla riga: 1292
# Sono arrivato alla riga: 1293
# Sono arrivato alla riga: 1294
# Sono arrivato alla riga: 1295
# Sono arrivato alla riga: 1296
# Sono arrivato alla riga: 1297
# Sono arrivato alla riga: 1298
# Sono arrivato alla riga: 1299
# Sono arrivato alla riga: 1300
# Sono arrivato alla riga: 1301
# Sono arrivato alla riga: 1302
# Sono arrivato alla riga: 1303
# Sono arrivato alla riga: 1304
# Sono arrivato alla riga: 1305
# Sono arrivato alla riga: 1306
# Sono arrivato alla riga: 1307
# Sono arrivato alla riga: 1308
# Sono arrivato alla riga: 1309
# Sono arrivato alla riga: 1310
# Sono arrivato alla riga: 1311
# Sono arrivato alla riga: 1312
# Sono arrivato alla riga: 1313
# Sono arrivato alla riga: 1314
# Sono arrivato alla riga: 1315
# Sono arrivato alla riga: 1316
# Sono arrivato alla riga: 1317
# Sono arrivato alla riga: 1318
# Sono arrivato alla riga: 1319
# Sono arrivato alla riga: 1320
# Sono arrivato alla riga: 1321
# Sono arrivato alla riga: 1322
# Sono arrivato alla riga: 1323
# Sono arrivato alla riga: 1324
# Sono arrivato alla riga: 1325
# Sono arrivato alla riga: 1326
# Sono arrivato alla riga: 1327
# Sono arrivato alla riga: 1328
# Sono arrivato alla riga: 1329
# Sono arrivato alla riga: 1330
# Sono arrivato alla riga: 1331
# Sono arrivato alla riga: 1332
# Sono arrivato alla riga: 1333
# Sono arrivato alla riga: 1334
# Sono arrivato alla riga: 1335
# Sono arrivato alla riga: 1336
# Sono arrivato alla riga: 1337
# Sono arrivato alla riga: 1338
# Sono arrivato alla riga: 1339
# Sono arrivato alla riga: 1340
# Sono arrivato alla riga: 1341
# Sono arrivato alla riga: 1342
# Sono arrivato alla riga: 1343
# Sono arrivato alla riga: 1344
# Sono arrivato alla riga: 1345
# Sono arrivato alla riga: 1346
# Sono arrivato alla riga: 1347
# Sono arrivato alla riga: 1348
# Sono arrivato alla riga: 1349
# Sono arrivato alla riga: 1350
# Sono arrivato alla riga: 1351
# Sono arrivato alla riga: 1352
# Sono arrivato alla riga: 1353
# Sono arrivato alla riga: 1354
# Sono arrivato alla riga: 1355
# Sono arrivato alla riga: 1356
# Sono arrivato alla riga: 1357
# Sono arrivato alla riga: 1358
# Sono arrivato alla riga: 1359
# Sono arrivato alla riga: 1360
# Sono arrivato alla riga: 1361
# Sono arrivato alla riga: 1362
# Sono arrivato alla riga: 1363
# Sono arrivato alla riga: 1364
# Sono arrivato alla riga: 1365
# Sono arrivato alla riga: 1366
# Sono arrivato alla riga: 1367
# Sono arrivato alla riga: 1368
# Sono arrivato alla riga: 1369
# Sono arrivato alla riga: 1370
# Sono arrivato alla riga: 1371
# Sono arrivato alla riga: 1372
# Sono arrivato alla riga: 1373
# Sono arrivato alla riga: 1374
# Sono arrivato alla riga: 1375
# Sono arrivato alla riga: 1376
# Sono arrivato alla riga: 1377
# Sono arrivato alla riga: 1378
# Sono arrivato alla riga: 1379
# Sono arrivato alla riga: 1380
# Sono arrivato alla riga: 1381
# Sono arrivato alla riga: 1382
# Sono arrivato alla riga: 1383
# Sono arrivato alla riga: 1384
# Sono arrivato alla riga: 1385
# Sono arrivato alla riga: 1386
# Sono arrivato alla riga: 1387
# Sono arrivato alla riga: 1388
# Sono arrivato alla riga: 1389
# Sono arrivato alla riga: 1390
# Sono arrivato alla riga: 1391
# Sono arrivato alla riga: 1392
# Sono arrivato alla riga: 1393
# Sono arrivato alla riga: 1394
# Sono arrivato alla riga: 1395
# Sono arrivato alla riga: 1396
# Sono arrivato alla riga: 1397
# Sono arrivato alla riga: 1398
# Sono arrivato alla riga: 1399
# Sono arrivato alla riga: 1400
# Sono arrivato alla riga: 1401
# Sono arrivato alla riga: 1402
# Sono arrivato alla riga: 1403
# Sono arrivato alla riga: 1404
# Sono arrivato alla riga: 1405
# Sono arrivato alla riga: 1406
# Sono arrivato alla riga: 1407
# Sono arrivato alla riga: 1408
# Sono arrivato alla riga: 1409
# Sono arrivato alla riga: 1410
# Sono arrivato alla riga: 1411
# Sono arrivato alla riga: 1412
# Sono arrivato alla riga: 1413
# Sono arrivato alla riga: 1414
# Sono arrivato alla riga: 1415
# Sono arrivato alla riga: 1416
# Sono arrivato alla riga: 1417
# Sono arrivato alla riga: 1418
# Sono arrivato alla riga: 1419
# Sono arrivato alla riga: 1420
# Sono arrivato alla riga: 1421
# Sono arrivato alla riga: 1422
# Sono arrivato alla riga: 1423
# Sono arrivato alla riga: 1424
# Sono arrivato alla riga: 1425
# Sono arrivato alla riga: 1426
# Sono arrivato alla riga: 1427
# Sono arrivato alla riga: 1428
# Sono arrivato alla riga: 1429
# Sono arrivato alla riga: 1430
# Sono arrivato alla riga: 1431
# Sono arrivato alla riga: 1432
# Sono arrivato alla riga: 1433
# Sono arrivato alla riga: 1434
# Sono arrivato alla riga: 1435
# Sono arrivato alla riga: 1436
# Sono arrivato alla riga: 1437
# Sono arrivato alla riga: 1438
# Sono arrivato alla riga: 1439
# Sono arrivato alla riga: 1440
# Sono arrivato alla riga: 1441
# Sono arrivato alla riga: 1442
# Sono arrivato alla riga: 1443
# Sono arrivato alla riga: 1444
# Sono arrivato alla riga: 1445
# Sono arrivato alla riga: 1446
# Sono arrivato alla riga: 1447
# Sono arrivato alla riga: 1448
# Sono arrivato alla riga: 1449
# Sono arrivato alla riga: 1450
# Sono arrivato alla riga: 1451
# Sono arrivato alla riga: 1452
# Sono arrivato alla riga: 1453
# Sono arrivato alla riga: 1454
# Sono arrivato alla riga: 1455
# Sono arrivato alla riga: 1456
# Sono arrivato alla riga: 1457
# Sono arrivato alla riga: 1458
# Sono arrivato alla riga: 1459
# Sono arrivato alla riga: 1460
# Sono arrivato alla riga: 1461
# Sono arrivato alla riga: 1462
# Sono arrivato alla riga: 1463
# Sono arrivato alla riga: 1464
# Sono arrivato alla riga: 1465
# Sono arrivato alla riga: 1466
# Sono arrivato alla riga: 1467
# Sono arrivato alla riga: 1468
# Sono arrivato alla riga: 1469
# Sono arrivato alla riga: 1470
# Sono arrivato alla riga: 1471
# Sono arrivato alla riga: 1472
# Sono arrivato alla riga: 1473
# Sono arrivato alla riga: 1474
# Sono arrivato alla riga: 1475
# Sono arrivato alla riga: 1476
# Sono arrivato alla riga: 1477
# Sono arrivato alla riga: 1478
# Sono arrivato alla riga: 1479
# Sono arrivato alla riga: 1480
# Sono arrivato alla riga: 1481
# Sono arrivato alla riga: 1482
# Sono arrivato alla riga: 1483
# Sono arrivato alla riga: 1484
# Sono arrivato alla riga: 1485
# Sono arrivato alla riga: 1486
# Sono arrivato alla riga: 1487
# Sono arrivato alla riga: 1488
# Sono arrivato alla riga: 1489
# Sono arrivato alla riga: 1490
# Sono arrivato alla riga: 1491
# Sono arrivato alla riga: 1492
# Sono arrivato alla riga: 1493
# Sono arrivato alla riga: 1494
# Sono arrivato alla riga: 1495
# Sono arrivato alla riga: 1496
# Sono arrivato alla riga: 1497
# Sono arrivato alla riga: 1498
# Sono arrivato alla riga: 1499
# Sono arrivato alla riga: 1500
# Sono arrivato alla riga: 1501
# Sono arrivato alla riga: 1502
# Sono arrivato alla riga: 1503
# Sono arrivato alla riga: 1504
# Sono arrivato alla riga: 1505
# Sono arrivato alla riga: 1506
# Sono arrivato alla riga: 1507
# Sono arrivato alla riga: 1508
# Sono arrivato alla riga: 1509
# Sono arrivato alla riga: 1510
# Sono arrivato alla riga: 1511
# Sono arrivato alla riga: 1512
# Sono arrivato alla riga: 1513
# Sono arrivato alla riga: 1514
# Sono arrivato alla riga: 1515
# Sono arrivato alla riga: 1516
# Sono arrivato alla riga: 1517
# Sono arrivato alla riga: 1518
# Sono arrivato alla riga: 1519
# Sono arrivato alla riga: 1520
# Sono arrivato alla riga: 1521
# Sono arrivato alla riga: 1522
# Sono arrivato alla riga: 1523
# Sono arrivato alla riga: 1524
# Sono arrivato alla riga: 1525
# Sono arrivato alla riga: 1526
# Sono arrivato alla riga: 1527
# Sono arrivato alla riga: 1528
# Sono arrivato alla riga: 1529
# Sono arrivato alla riga: 1530
# Sono arrivato alla riga: 1531
# Sono arrivato alla riga: 1532
# Sono arrivato alla riga: 1533
# Sono arrivato alla riga: 1534
# Sono arrivato alla riga: 1535
# Sono arrivato alla riga: 1536
# Sono arrivato alla riga: 1537
# Sono arrivato alla riga: 1538
# Sono arrivato alla riga: 1539
# Sono arrivato alla riga: 1540
# Sono arrivato alla riga: 1541
# Sono arrivato alla riga: 1542
# Sono arrivato alla riga: 1543
# Sono arrivato alla riga: 1544
# Sono arrivato alla riga: 1545
# Sono arrivato alla riga: 1546
# Sono arrivato alla riga: 1547
# Sono arrivato alla riga: 1548
# Sono arrivato alla riga: 1549
# Sono arrivato alla riga: 1550
# Sono arrivato alla riga: 1551
# Sono arrivato alla riga: 1552
# Sono arrivato alla riga: 1553
# Sono arrivato alla riga: 1554
# Sono arrivato alla riga: 1555
# Sono arrivato alla riga: 1556
# Sono arrivato alla riga: 1557
# Sono arrivato alla riga: 1558
# Sono arrivato alla riga: 1559
# Sono arrivato alla riga: 1560
# Sono arrivato alla riga: 1561
# Sono arrivato alla riga: 1562
# Sono arrivato alla riga: 1563
# Sono arrivato alla riga: 1564
# Sono arrivato alla riga: 1565
# Sono arrivato alla riga: 1566
# Sono arrivato alla riga: 1567
# Sono arrivato alla riga: 1568
# Sono arrivato alla riga: 1569
# Sono arrivato alla riga: 1570
# Sono arrivato alla riga: 1571
# Sono arrivato alla riga: 1572
# Sono arrivato alla riga: 1573
# Sono arrivato alla riga: 1574
# Sono arrivato alla riga: 1575
# Sono arrivato alla riga: 1576
# Sono arrivato alla riga: 1577
# Sono arrivato alla riga: 1578
# Sono arrivato alla riga: 1579
# Sono arrivato alla riga: 1580
# Sono arrivato alla riga: 1581
# Sono arrivato alla riga: 1582
# Sono arrivato alla riga: 1583
# Sono arrivato alla riga: 1584
# Sono arrivato alla riga: 1585
# Sono arrivato alla riga: 1586
# Sono arrivato alla riga: 1587
# Sono arrivato alla riga: 1588
# Sono arrivato alla riga: 1589
# Sono arrivato alla riga: 1590
# Sono arrivato alla riga: 1591
# Sono arrivato alla riga: 1592
# Sono arrivato alla riga: 1593
# Sono arrivato alla riga: 1594
# Sono arrivato alla riga: 1595
# Sono arrivato alla riga: 1596
# Sono arrivato alla riga: 1597
# Sono arrivato alla riga: 1598
# Sono arrivato alla riga: 1599
# Sono arrivato alla riga: 1600
# Sono arrivato alla riga: 1601
# Sono arrivato alla riga: 1602
# Sono arrivato alla riga: 1603
# Sono arrivato alla riga: 1604
# Sono arrivato alla riga: 1605
# Sono arrivato alla riga: 1606
# Sono arrivato alla riga: 1607
# Sono arrivato alla riga: 1608
# Sono arrivato alla riga: 1609
# Sono arrivato alla riga: 1610
# Sono arrivato alla riga: 1611
# Sono arrivato alla riga: 1612
# Sono arrivato alla riga: 1613
# Sono arrivato alla riga: 1614
# Sono arrivato alla riga: 1615
# Sono arrivato alla riga: 1616
# Sono arrivato alla riga: 1617
# Sono arrivato alla riga: 1618
# Sono arrivato alla riga: 1619
# Sono arrivato alla riga: 1620
# Sono arrivato alla riga: 1621
# Sono arrivato alla riga: 1622
# Sono arrivato alla riga: 1623
# Sono arrivato alla riga: 1624
# Sono arrivato alla riga: 1625
# Sono arrivato alla riga: 1626
# Sono arrivato alla riga: 1627
# Sono arrivato alla riga: 1628
# Sono arrivato alla riga: 1629
# Sono arrivato alla riga: 1630
# Sono arrivato alla riga: 1631
# Sono arrivato alla riga: 1632
# Sono arrivato alla riga: 1633
# Sono arrivato alla riga: 1634
# Sono arrivato alla riga: 1635
# Sono arrivato alla riga: 1636
# ...
# Sono arrivato alla riga: 2400
# Sono arrivato alla riga: 2401
# Sono arrivato alla riga: 2402
# Sono arrivato alla riga: 2403
# Sono arrivato alla riga: 2404
# Sono arrivato alla riga: 2405
# Sono arrivato alla riga: 2406
# Sono arrivato alla riga: 2407
# Sono arrivato alla riga: 2408
# Sono arrivato alla riga: 2409
# Sono arrivato alla riga: 2410
# Sono arrivato alla riga: 2411
# Sono arrivato alla riga: 2412
# Sono arrivato alla riga: 2413
# Sono arrivato alla riga: 2414
# Sono arrivato alla riga: 2415
# Sono arrivato alla riga: 2416
# Sono arrivato alla riga: 2417
# Sono arrivato alla riga: 2418
# Sono arrivato alla riga: 2419
# Sono arrivato alla riga: 2420
# Sono arrivato alla riga: 2421
# Sono arrivato alla riga: 2422
# Sono arrivato alla riga: 2423
# Sono arrivato alla riga: 2424
# Sono arrivato alla riga: 2425
# Sono arrivato alla riga: 2426
# Sono arrivato alla riga: 2427
# Sono arrivato alla riga: 2428
# Sono arrivato alla riga: 2429
# Sono arrivato alla riga: 2430
# Sono arrivato alla riga: 2431
# Sono arrivato alla riga: 2432
# Sono arrivato alla riga: 2433
# Sono arrivato alla riga: 2434
# Sono arrivato alla riga: 2435
# Sono arrivato alla riga: 2436
# Sono arrivato alla riga: 2437
# Sono arrivato alla riga: 2438
# Sono arrivato alla riga: 2439
# Sono arrivato alla riga: 2440
# Sono arrivato alla riga: 2441
# Sono arrivato alla riga: 2442
# Sono arrivato alla riga: 2443
# Sono arrivato alla riga: 2444
# Sono arrivato alla riga: 2445
# Sono arrivato alla riga: 2446
# Sono arrivato alla riga: 2447
# Sono arrivato alla riga: 2448
# Sono arrivato alla riga: 2449
# Sono arrivato alla riga: 2450
# Sono arrivato alla riga: 2451
# Sono arrivato alla riga: 2452
# Sono arrivato alla riga: 2453
# Sono arrivato alla riga: 2454
# Sono arrivato alla riga: 2455
# Sono arrivato alla riga: 2456
# Sono arrivato alla riga: 2457
# Sono arrivato alla riga: 2458
# Sono arrivato alla riga: 2459
# Sono arrivato alla riga: 2460
# Sono arrivato alla riga: 2461
# Sono arrivato alla riga: 2462
# Sono arrivato alla riga: 2463
# Sono arrivato alla riga: 2464
# Sono arrivato alla riga: 2465
# Sono arrivato alla riga: 2466
# Sono arrivato alla riga: 2467
# Sono arrivato alla riga: 2468
# Sono arrivato alla riga: 2469
# Sono arrivato alla riga: 2470
# Sono arrivato alla riga: 2471
# Sono arrivato alla riga: 2472
# Sono arrivato alla riga: 2473
# Sono arrivato alla riga: 2474
# Sono arrivato alla riga: 2475
# Sono arrivato alla riga: 2476
# Sono arrivato alla riga: 2477
# Sono arrivato alla riga: 2478
# Sono arrivato alla riga: 2479
# Sono arrivato alla riga: 2480
# Sono arrivato alla riga: 2481
# Sono arrivato alla riga: 2482
# Sono arrivato alla riga: 2483
# Sono arrivato alla riga: 2484
# Sono arrivato alla riga: 2485
# Sono arrivato alla riga: 2486
# Sono arrivato alla riga: 2487
# Sono arrivato alla riga: 2488
# Sono arrivato alla riga: 2489
# Sono arrivato alla riga: 2490
# Sono arrivato alla riga: 2491
# Sono arrivato alla riga: 2492
# Sono arrivato alla riga: 2493
# Sono arrivato alla riga: 2494
# Sono arrivato alla riga: 2495
# Sono arrivato alla riga: 2496
# Sono arrivato alla riga: 2497
# Sono arrivato alla riga: 2498
# Sono arrivato alla riga: 2499
# Sono arrivato alla riga: 2500
# Sono arrivato alla riga: 2501
# Sono arrivato alla riga: 2502
# Sono arrivato alla riga: 2503
# Sono arrivato alla riga: 2504
# Sono arrivato alla riga: 2505
# Sono arrivato alla riga: 2506
# Sono arrivato alla riga: 2507
# Sono arrivato alla riga: 2508
# Sono arrivato alla riga: 2509
# Sono arrivato alla riga: 2510
# Sono arrivato alla riga: 2511
# Sono arrivato alla riga: 2512
# Sono arrivato alla riga: 2513
# Sono arrivato alla riga: 2514
# Sono arrivato alla riga: 2515
# Sono arrivato alla riga: 2516
# Sono arrivato alla riga: 2517
# Sono arrivato alla riga: 2518
# Sono arrivato alla riga: 2519
# Sono arrivato alla riga: 2520
# Sono arrivato alla riga: 2521
# Sono arrivato alla riga: 2522
# Sono arrivato alla riga: 2523
# Sono arrivato alla riga: 2524
# Sono arrivato alla riga: 2525
# Sono arrivato alla riga: 2526
# Sono arrivato alla riga: 2527
# Sono arrivato alla riga: 2528
# Sono arrivato alla riga: 2529
# Sono arrivato alla riga: 2530
# Sono arrivato alla riga: 2531
# Sono arrivato alla riga: 2532
# Sono arrivato alla riga: 2533
# Sono arrivato alla riga: 2534
# Sono arrivato alla riga: 2535
# Sono arrivato alla riga: 2536
# Sono arrivato alla riga: 2537
# Sono arrivato alla riga: 2538
# Sono arrivato alla riga: 2539
# Sono arrivato alla riga: 2540
# Sono arrivato alla riga: 2541
# Sono arrivato alla riga: 2542
# Sono arrivato alla riga: 2543
# Sono arrivato alla riga: 2544
# Sono arrivato alla riga: 2545
# Sono arrivato alla riga: 2546
# Sono arrivato alla riga: 2547
# Sono arrivato alla riga: 2548
# Sono arrivato alla riga: 2549
# Sono arrivato alla riga: 2550
# Sono arrivato alla riga: 2551
# Sono arrivato alla riga: 2552
# Sono arrivato alla riga: 2553
# Sono arrivato alla riga: 2554
# Sono arrivato alla riga: 2555
# Sono arrivato alla riga: 2556
# Sono arrivato alla riga: 2557
# Sono arrivato alla riga: 2558
# Sono arrivato alla riga: 2559
# Sono arrivato alla riga: 2560
# Sono arrivato alla riga: 2561
# Sono arrivato alla riga: 2562
# Sono arrivato alla riga: 2563
# Sono arrivato alla riga: 2564
# Sono arrivato alla riga: 2565
# Sono arrivato alla riga: 2566
# Sono arrivato alla riga: 2567
# Sono arrivato alla riga: 2568
# Sono arrivato alla riga: 2569
# Sono arrivato alla riga: 2570
# Sono arrivato alla riga: 2571
# Sono arrivato alla riga: 2572
# Sono arrivato alla riga: 2573
# Sono arrivato alla riga: 2574
# Sono arrivato alla riga: 2575
# Sono arrivato alla riga: 2576
# Sono arrivato alla riga: 2577
# Sono arrivato alla riga: 2578
# Sono arrivato alla riga: 2579
# Sono arrivato alla riga: 2580
# Sono arrivato alla riga: 2581
# Sono arrivato alla riga: 2582
# Sono arrivato alla riga: 2583
# Sono arrivato alla riga: 2584
# Sono arrivato alla riga: 2585
# Sono arrivato alla riga: 2586
# Sono arrivato alla riga: 2587
# Sono arrivato alla riga: 2588
# Sono arrivato alla riga: 2589
# Sono arrivato alla riga: 2590
# Sono arrivato alla riga: 2591
# Sono arrivato alla riga: 2592
# Sono arrivato alla riga: 2593
# Sono arrivato alla riga: 2594
# Sono arrivato alla riga: 2595
# Sono arrivato alla riga: 2596
# Sono arrivato alla riga: 2597
# Sono arrivato alla riga: 2598
# Sono arrivato alla riga: 2599
# Sono arrivato alla riga: 2600
# Sono arrivato alla riga: 2601
# Sono arrivato alla riga: 2602
# Sono arrivato alla riga: 2603
# Sono arrivato alla riga: 2604
# Sono arrivato alla riga: 2605
# Sono arrivato alla riga: 2606
# Sono arrivato alla riga: 2607
# Sono arrivato alla riga: 2608
# Sono arrivato alla riga: 2609
# Sono arrivato alla riga: 2610
# Sono arrivato alla riga: 2611
# Sono arrivato alla riga: 2612
# Sono arrivato alla riga: 2613
# Sono arrivato alla riga: 2614
# Sono arrivato alla riga: 2615
# Sono arrivato alla riga: 2616
# Sono arrivato alla riga: 2617
# Sono arrivato alla riga: 2618
# Sono arrivato alla riga: 2619
# Sono arrivato alla riga: 2620
# Sono arrivato alla riga: 2621
# Sono arrivato alla riga: 2622
# Sono arrivato alla riga: 2623
# Sono arrivato alla riga: 2624
# Sono arrivato alla riga: 2625
# Sono arrivato alla riga: 2626
# Sono arrivato alla riga: 2627
# Sono arrivato alla riga: 2628
# Sono arrivato alla riga: 2629
# Sono arrivato alla riga: 2630
# Sono arrivato alla riga: 2631
# Sono arrivato alla riga: 2632
# Sono arrivato alla riga: 2633
# Sono arrivato alla riga: 2634
# Sono arrivato alla riga: 2635
# Sono arrivato alla riga: 2636
# Sono arrivato alla riga: 2637
# Sono arrivato alla riga: 2638
# Sono arrivato alla riga: 2639
# Sono arrivato alla riga: 2640
# Sono arrivato alla riga: 2641
# Sono arrivato alla riga: 2642
# Sono arrivato alla riga: 2643
# Sono arrivato alla riga: 2644
# Sono arrivato alla riga: 2645
# Sono arrivato alla riga: 2646
# Sono arrivato alla riga: 2647
# Sono arrivato alla riga: 2648
# Sono arrivato alla riga: 2649
# Sono arrivato alla riga: 2650
# Sono arrivato alla riga: 2651
# Sono arrivato alla riga: 2652
# Sono arrivato alla riga: 2653
# Sono arrivato alla riga: 2654
# Sono arrivato alla riga: 2655
# Sono arrivato alla riga: 2656
# Sono arrivato alla riga: 2657
# Sono arrivato alla riga: 2658
# Sono arrivato alla riga: 2659
# Sono arrivato alla riga: 2660
# Sono arrivato alla riga: 2661
# Sono arrivato alla riga: 2662
# Sono arrivato alla riga: 2663
# Sono arrivato alla riga: 2664
# Sono arrivato alla riga: 2665
# Sono arrivato alla riga: 2666
# Sono arrivato alla riga: 2667
# Sono arrivato alla riga: 2668
# Sono arrivato alla riga: 2669
# Sono arrivato alla riga: 2670
# Sono arrivato alla riga: 2671
# Sono arrivato alla riga: 2672
# Sono arrivato alla riga: 2673
# Sono arrivato alla riga: 2674
# Sono arrivato alla riga: 2675
# Sono arrivato alla riga: 2676
# Sono arrivato alla riga: 2677
# Sono arrivato alla riga: 2678
# Sono arrivato alla riga: 2679
# Sono arrivato alla riga: 2680
# Sono arrivato alla riga: 2681
# Sono arrivato alla riga: 2682
# Sono arrivato alla riga: 2683
# Sono arrivato alla riga: 2684
# Sono arrivato alla riga: 2685
# Sono arrivato alla riga: 2686
# Sono arrivato alla riga: 2687
# Sono arrivato alla riga: 2688
# Sono arrivato alla riga: 2689
# Sono arrivato alla riga: 2690
# Sono arrivato alla riga: 2691
# Sono arrivato alla riga: 2692
# Sono arrivato alla riga: 2693
# Sono arrivato alla riga: 2694
# Sono arrivato alla riga: 2695
# Sono arrivato alla riga: 2696
# Sono arrivato alla riga: 2697
# Sono arrivato alla riga: 2698
# Sono arrivato alla riga: 2699
# Sono arrivato alla riga: 2700
# Sono arrivato alla riga: 2701
# Sono arrivato alla riga: 2702
# Sono arrivato alla riga: 2703
# Sono arrivato alla riga: 2704
# Sono arrivato alla riga: 2705
# Sono arrivato alla riga: 2706
# Sono arrivato alla riga: 2707
# Sono arrivato alla riga: 2708
# Sono arrivato alla riga: 2709
# Sono arrivato alla riga: 2710
# Sono arrivato alla riga: 2711
# Sono arrivato alla riga: 2712
# Sono arrivato alla riga: 2713
# Sono arrivato alla riga: 2714
# Sono arrivato alla riga: 2715
# Sono arrivato alla riga: 2716
# Sono arrivato alla riga: 2717
# Sono arrivato alla riga: 2718
# Sono arrivato alla riga: 2719
# Sono arrivato alla riga: 2720
# Sono arrivato alla riga: 2721
# Sono arrivato alla riga: 2722
# Sono arrivato alla riga: 2723
# Sono arrivato alla riga: 2724
# Sono arrivato alla riga: 2725
# Sono arrivato alla riga: 2726
# Sono arrivato alla riga: 2727
# Sono arrivato alla riga: 2728
# Sono arrivato alla riga: 2729
# Sono arrivato alla riga: 2730
# Sono arrivato alla riga: 2731
# Sono arrivato alla riga: 2732
# Sono arrivato alla riga: 2733
# Sono arrivato alla riga: 2734
# Sono arrivato alla riga: 2735
# Sono arrivato alla riga: 2736
# Sono arrivato alla riga: 2737
# Sono arrivato alla riga: 2738
# Sono arrivato alla riga: 2739
# Sono arrivato alla riga: 2740
# Sono arrivato alla riga: 2741
# Sono arrivato alla riga: 2742
# Sono arrivato alla riga: 2743
# Sono arrivato alla riga: 2744
# Sono arrivato alla riga: 2745
# Sono arrivato alla riga: 2746
# Sono arrivato alla riga: 2747
# Sono arrivato alla riga: 2748
# Sono arrivato alla riga: 2749
# Sono arrivato alla riga: 2750
# Sono arrivato alla riga: 2751
# Sono arrivato alla riga: 2752
# Sono arrivato alla riga: 2753
# Sono arrivato alla riga: 2754
# Sono arrivato alla riga: 2755
# Sono arrivato alla riga: 2756
# Sono arrivato alla riga: 2757
# Sono arrivato alla riga: 2758
# Sono arrivato alla riga: 2759
# Sono arrivato alla riga: 2760
# Sono arrivato alla riga: 2761
# Sono arrivato alla riga: 2762
# Sono arrivato alla riga: 2763
# Sono arrivato alla riga: 2764
# Sono arrivato alla riga: 2765
# Sono arrivato alla riga: 2766
# Sono arrivato alla riga: 2767
# Sono arrivato alla riga: 2768
# Sono arrivato alla riga: 2769
# Sono arrivato alla riga: 2770
# Sono arrivato alla riga: 2771
# Sono arrivato alla riga: 2772
# Sono arrivato alla riga: 2773
# Sono arrivato alla riga: 2774
# Sono arrivato alla riga: 2775
# Sono arrivato alla riga: 2776
# Sono arrivato alla riga: 2777
# Sono arrivato alla riga: 2778
# Sono arrivato alla riga: 2779
# Sono arrivato alla riga: 2780
# Sono arrivato alla riga: 2781
# Sono arrivato alla riga: 2782
# Sono arrivato alla riga: 2783
# Sono arrivato alla riga: 2784
# Sono arrivato alla riga: 2785
# Sono arrivato alla riga: 2786
# Sono arrivato alla riga: 2787
# Sono arrivato alla riga: 2788
# Sono arrivato alla riga: 2789
# Sono arrivato alla riga: 2790
# Sono arrivato alla riga: 2791
# Sono arrivato alla riga: 2792
# Sono arrivato alla riga: 2793
# Sono arrivato alla riga: 2794
# Sono arrivato alla riga: 2795
# Sono arrivato alla riga: 2796
# Sono arrivato alla riga: 2797
# Sono arrivato alla riga: 2798
# Sono arrivato alla riga: 2799
# Sono arrivato alla riga: 2800
# Sono arrivato alla riga: 2801
# Sono arrivato alla riga: 2802
# Sono arrivato alla riga: 2803
# Sono arrivato alla riga: 2804
# Sono arrivato alla riga: 2805
# Sono arrivato alla riga: 2806
# Sono arrivato alla riga: 2807
# Sono arrivato alla riga: 2808
# Sono arrivato alla riga: 2809
# Sono arrivato alla riga: 2810
# Sono arrivato alla riga: 2811
# Sono arrivato alla riga: 2812
# Sono arrivato alla riga: 2813
# Sono arrivato alla riga: 2814
# Sono arrivato alla riga: 2815
# Sono arrivato alla riga: 2816
# Sono arrivato alla riga: 2817
# Sono arrivato alla riga: 2818
# Sono arrivato alla riga: 2819
# Sono arrivato alla riga: 2820
# Sono arrivato alla riga: 2821
# Sono arrivato alla riga: 2822
# Sono arrivato alla riga: 2823
# Sono arrivato alla riga: 2824
# Sono arrivato alla riga: 2825
# Sono arrivato alla riga: 2826
# Sono arrivato alla riga: 2827
# Sono arrivato alla riga: 2828
# Sono arrivato alla riga: 2829
# Sono arrivato alla riga: 2830
# Sono arrivato alla riga: 2831
# Sono arrivato alla riga: 2832
# Sono arrivato alla riga: 2833
# Sono arrivato alla riga: 2834
# Sono arrivato alla riga: 2835
# Sono arrivato alla riga: 2836
# Sono arrivato alla riga: 2837
# Sono arrivato alla riga: 2838
# Sono arrivato alla riga: 2839
# Sono arrivato alla riga: 2840
# Sono arrivato alla riga: 2841
# Sono arrivato alla riga: 2842
# Sono arrivato alla riga: 2843
# Sono arrivato alla riga: 2844
# Sono arrivato alla riga: 2845
# Sono arrivato alla riga: 2846
# Sono arrivato alla riga: 2847
# Sono arrivato alla riga: 2848
# Sono arrivato alla riga: 2849
# Sono arrivato alla riga: 2850
# Sono arrivato alla riga: 2851
# Sono arrivato alla riga: 2852
# Sono arrivato alla riga: 2853
# Sono arrivato alla riga: 2854
# Sono arrivato alla riga: 2855
# Sono arrivato alla riga: 2856
# Sono arrivato alla riga: 2857
# Sono arrivato alla riga: 2858
# Sono arrivato alla riga: 2859
# Sono arrivato alla riga: 2860
# Sono arrivato alla riga: 2861
# Sono arrivato alla riga: 2862
# Sono arrivato alla riga: 2863
# Sono arrivato alla riga: 2864
# Sono arrivato alla riga: 2865
# Sono arrivato alla riga: 2866
# Sono arrivato alla riga: 2867
# Sono arrivato alla riga: 2868
# Sono arrivato alla riga: 2869
# Sono arrivato alla riga: 2870
# Sono arrivato alla riga: 2871
# Sono arrivato alla riga: 2872
# Sono arrivato alla riga: 2873
# Sono arrivato alla riga: 2874
# Sono arrivato alla riga: 2875
# Sono arrivato alla riga: 2876
# Sono arrivato alla riga: 2877
# Sono arrivato alla riga: 2878
# Sono arrivato alla riga: 2879
# Sono arrivato alla riga: 2880
# Sono arrivato alla riga: 2881
# Sono arrivato alla riga: 2882
# Sono arrivato alla riga: 2883
# Sono arrivato alla riga: 2884
# Sono arrivato alla riga: 2885
# Sono arrivato alla riga: 2886
# Sono arrivato alla riga: 2887
# Sono arrivato alla riga: 2888
# Sono arrivato alla riga: 2889
# Sono arrivato alla riga: 2890
# Sono arrivato alla riga: 2891
# Sono arrivato alla riga: 2892
# Sono arrivato alla riga: 2893
# Sono arrivato alla riga: 2894
# Sono arrivato alla riga: 2895
# Sono arrivato alla riga: 2896
# Sono arrivato alla riga: 2897
# Sono arrivato alla riga: 2898
# Sono arrivato alla riga: 2899
# Sono arrivato alla riga: 2900
# Sono arrivato alla riga: 2901
# Sono arrivato alla riga: 2902
# Sono arrivato alla riga: 2903
# Sono arrivato alla riga: 2904
# Sono arrivato alla riga: 2905
# Sono arrivato alla riga: 2906
# Sono arrivato alla riga: 2907
# Sono arrivato alla riga: 2908
# Sono arrivato alla riga: 2909
# Sono arrivato alla riga: 2910
# Sono arrivato alla riga: 2911
# Sono arrivato alla riga: 2912
# Sono arrivato alla riga: 2913
# Sono arrivato alla riga: 2914
# Sono arrivato alla riga: 2915
# Sono arrivato alla riga: 2916
# Sono arrivato alla riga: 2917
# Sono arrivato alla riga: 2918
# Sono arrivato alla riga: 2919
# Sono arrivato alla riga: 2920
# Sono arrivato alla riga: 2921
# Sono arrivato alla riga: 2922
# Sono arrivato alla riga: 2923
# Sono arrivato alla riga: 2924
# Sono arrivato alla riga: 2925
# Sono arrivato alla riga: 2926
# Sono arrivato alla riga: 2927
# Sono arrivato alla riga: 2928
# Sono arrivato alla riga: 2929
# Sono arrivato alla riga: 2930
# Sono arrivato alla riga: 2931
# Sono arrivato alla riga: 2932

# %% [markdown]
# # TRAINING AND TEST

# %%
path_df_train = '/content/drive/MyDrive/ProjectDSL/Data/Dataset_finali/train_Saro_features_trimmed_speed_acc_mfcc_acf.csv'
path_df_eval = '/content/drive/MyDrive/ProjectDSL/Data/Dataset_finali/eval_Saro_features_trimmed_speed_acc_mfcc_acf.csv'

# %% [markdown]
# #### TRAINING FUNCTIONS

# %%
def find_best_model(X_train, X_test, y_train, y_test):


    preprocessor = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler()),
    ])

    models = {
        'Random Forest': Pipeline(steps=[
            ('preprocessor', preprocessor),
            ('regressor', RandomForestRegressor(n_estimators=300, random_state=42))
        ]),

        'Support Vector Regressor': Pipeline(steps=[
          ('preprocessor', preprocessor),
          ('regressor', SVR(kernel='rbf', C= 10.769322731738809, epsilon=0.019314668917207987))
      ])
    }

    rmse_scores = {}
    error_details = {}

    for model_name, model_pipeline in models.items():
        model_pipeline.fit(X_train, y_train)

        y_pred = model_pipeline.predict(X_test)

        mse = mean_squared_error(y_test, y_pred)
        rmse = np.sqrt(mse)

        rmse_scores[model_name] = rmse

        errors = np.abs(y_test - y_pred)

        print(f"{model_name} - RMSE: {rmse}")

    best_model_name = min(rmse_scores, key=rmse_scores.get)
    best_rmse = rmse_scores[best_model_name]

    print(f"\nIl miglior modello è {best_model_name} con RMSE = {best_rmse}")
    return best_model_name, best_rmse, models[best_model_name], rmse_scores

# %%
def run_for_plot(X_train, X_test, y_train, y_test):


    preprocessor = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler()),
    ])

    models = {


        'Support Vector Regressor': Pipeline(steps=[
          ('preprocessor', preprocessor),
          ('regressor', SVR(kernel='rbf', C= 10.769322731738809, epsilon=0.019314668917207987))
      ])
    }

    rmse_scores = {}
    error_details = {}

    for model_name, model_pipeline in models.items():
        model_pipeline.fit(X_train, y_train)

        y_pred = model_pipeline.predict(X_test)

        mse = mean_squared_error(y_test, y_pred)
        rmse = np.sqrt(mse)

        rmse_scores[model_name] = rmse

        errors = np.abs(y_test - y_pred)

        print(f"{model_name} - RMSE: {rmse}")

    best_model_name = min(rmse_scores, key=rmse_scores.get)
    best_rmse = rmse_scores[best_model_name]

    print(f"\nIl miglior modello è {best_model_name} con RMSE = {best_rmse}")
    return best_model_name, best_rmse, models[best_model_name], rmse_scores

# %%
def train(df_path,max_sample_cat):
  df_finale = pd.read_csv(df_path)
  train_df, test_df = train_test_split(df_finale, test_size=0.21, random_state=42)

  bins = range(0, int(train_df['age'].max()) + 2, 2)
  labels = [f"{i}-{i+1}" for i in bins[:-1]]

  train_df['age_group'] = pd.cut(train_df['age'], bins=bins, labels=labels, right=False)
  max_per_category = max_sample_cat

  def limit_samples(group):
      if len(group) > max_per_category:
          return group.sample(max_per_category, random_state=42)
      return group

  train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)

  train_df.drop(columns=['age_group'], inplace=True)

  X_train = train_df.loc[:, train_df.columns.difference(['Id', 'path', "age"])]
  y_train = train_df['age']

  X_test = test_df.loc[:, test_df.columns.difference(['Id', 'path', "age"])]
  y_test = test_df['age']

  best_model_name, best_rmse, best_model, rmse_scores = find_best_model(X_train,X_test, y_train, y_test)
  print(f"Miglior modello: {best_model_name}, RMSE: {best_rmse}")

  return best_model, X_train, train_df, test_df, best_rmse, rmse_scores, y_train,X_test,y_test

# %%
def final_eval_process(path, train_model):
  final_eval_df = pd.read_csv(path)
  final_eval_df.drop(columns=['Id', 'path'], inplace=True, errors='ignore')
  train_columns = train_model.columns.tolist()
  eval_columns = final_eval_df.columns.tolist()

  missing_in_eval = set(train_columns) - set(eval_columns)
  extra_in_eval = set(eval_columns) - set(train_columns)

  print("Colonne mancanti in final_eval_df:", missing_in_eval)
  print("Colonne extra in final_eval_df:", extra_in_eval)

  final_eval_df = final_eval_df[train_columns]
  return final_eval_df

# %%
def final_training(best_model,train_df, test_df):
  final_training_df = pd.concat([train_df, test_df])

  X_final = final_training_df.loc[:, final_training_df.columns.difference(['Id', 'path', "age"])]
  y_final = final_training_df['age']

  # Ultimo giro di training con tutti i dati
  best_model.fit(X_final, y_final)

# %% [markdown]
# #### TRAINING  AND TEST INTERFACE

# %%
best_model, x_train, train_df, test_df,best_rmse, rmse_scores ,y_train,x_test,y_test = train(path_df_train,150)
eval_df = final_eval_process(path_df_eval, x_train)

# %%
final_training(best_model, train_df, test_df)

# %%
predictions = best_model.predict(eval_df)

# Creare un DataFrame separato per la sottomissione
submission = pd.DataFrame({
    'Id': df_eval['Id'],
    'Predicted': predictions
})

submission = submission.sort_values(by='Id')

# Salvare in un file CSV
submission.to_csv('submission.csv', index=False)

# Scaricare il file
files.download('submission.csv')

# %% [markdown]
# # HYPERPARAMETER TUNING

# %% [markdown]
# #### FINE TUNING FUNCTIONS

# %%
def optuna_best_model(X_train, X_test, y_train, y_test):

    preprocessor = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler()),
    ])


    def objective(trial):
        kernel = trial.suggest_categorical("kernel", ["rbf"])
        C = trial.suggest_float("C", 10, 11, log=True)
        epsilon = trial.suggest_float("epsilon", 0.01, 0.02, log=True)

        model = Pipeline(steps=[
            ('preprocessor', preprocessor),
            ('regressor', SVR(kernel=kernel, C=C, epsilon=epsilon))
        ])


        score = cross_val_score(model, X_train, y_train, cv=3, scoring="neg_mean_squared_error", n_jobs=-1)
        return score.mean()

    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=50)

    best_params = study.best_params
    print(f"Migliori iperparametri trovati: {best_params}")

    best_model = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('regressor', SVR(
            kernel=best_params["kernel"],
            C=best_params["C"],
            epsilon=best_params["epsilon"]
        ))
    ])

    best_model.fit(X_train, y_train)

    y_pred = best_model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)

    print(f"Miglior modello RMSE sul test set: {rmse}")

    return best_model, rmse, best_params

# %%
def grid_search_random_forest(X_train, X_test, y_train, y_test):

    preprocessor = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler()),
    ])


    pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('regressor', RandomForestRegressor(random_state=42))
    ])


    param_grid = {
        'regressor__n_estimators': [100, 300],
        'regressor__max_depth': [5, 10, None],
    }

    # Grid Search
    grid_search = GridSearchCV(
        pipeline,
        param_grid,
        scoring='neg_mean_squared_error',
        cv=3,
        n_jobs=-1
    )
    grid_search.fit(X_train, y_train)


    best_params = grid_search.best_params_
    print(f"Migliori parametri trovati: {best_params}")


    best_model = grid_search.best_estimator_


    y_pred = best_model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)

    print(f"Miglior modello RMSE sul test set: {rmse}")

    return best_model, rmse, best_params

# %%
def find_best_configuration(df_path, max_sample_cat, model_name ):
  df_finale = pd.read_csv(df_path)
  train_df, test_df = train_test_split(df_finale, test_size=0.21, random_state=42)

  bins = range(0, int(train_df['age'].max()) + 2, 2)
  labels = [f"{i}-{i+1}" for i in bins[:-1]]

  train_df['age_group'] = pd.cut(train_df['age'], bins=bins, labels=labels, right=False)
  max_per_category = max_sample_cat

  def limit_samples(group):
      if len(group) > max_per_category:
          return group.sample(max_per_category, random_state=42)
      return group

  train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)

  train_df.drop(columns=['age_group'], inplace=True)

  x_train = train_df.loc[:, train_df.columns.difference(['Id', 'path', "age"])]
  y_train = train_df['age']

  x_test = test_df.loc[:, test_df.columns.difference(['Id', 'path', "age"])]
  y_test = test_df['age']
  if model_name == 'SVR':
    return optuna_best_model(x_train, x_test, y_train, y_test)
  if model_name == 'RF':
    return grid_search_random_forest(x_train, x_test, y_train, y_test)

# %% [markdown]
# #### FINE TUNING INTERFACE

# %%
best_model, rmse, best_params = find_best_configuration(path_df_train,450, 'RF') # Use SVR or RF
# Out:
# <ipython-input-91-7defa6b3b6c3>:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
# <ipython-input-91-7defa6b3b6c3>:16: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)

# %% [markdown]
# -----------------------------------------

# %% [markdown]
# #PLOT RESULTS

# %% [markdown]
# #### PLOTTING FUNCTIONS

# %%
def plot_rmse_by_sample_features(rmse_dict, title):
    plt.figure(figsize=(10, 6))

    for model, values in rmse_dict.items():

        if not values:
            continue

        # Sort values by max_sample_cat
        sorted_values = sorted(values, key=lambda x: x[0])
        sample_values = [n for n, _ in sorted_values]
        rmse_values = [rmse for _, rmse in sorted_values]

        # Create the plot
        plt.plot(sample_values, rmse_values, label=model, marker='o', linestyle='-')

    # Customize the x-axis
    if rmse_dict:
        all_samples = sorted({sample for model_values in rmse_dict.values() for sample, _ in model_values})
        plt.xticks(all_samples)

    plt.xlabel("n")
    plt.ylabel("RMSE")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
def train_feature(df_path,max_sample_cat):

  df_finale = pd.read_csv(df_path)

  # columns removed
  columns_to_drop = ['num_words', 'num_characters', 'num_pauses']
  df_finale = df_finale.drop(columns=columns_to_drop, errors='ignore')
  df_finale['tempo'] = df_finale['tempo'].astype(str).str.strip('[]').astype(float)

  # train and test set
  train_df, test_df = train_test_split(df_finale, test_size=0.21, random_state=42)


  bins = range(0, int(train_df['age'].max()) + 2, 2)
  labels = [f"{i}-{i+1}" for i in bins[:-1]]


  train_df['age_group'] = pd.cut(train_df['age'], bins=bins, labels=labels, right=False)
  max_per_category = max_sample_cat


  def limit_samples(group):
      if len(group) > max_per_category:
          return group.sample(max_per_category, random_state=42)
      return group


  train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
  train_df.drop(columns=['age_group'], inplace=True)

  # Final datasets
  X_train = train_df.loc[:, train_df.columns.difference(['Id', "sampling_rate", 'path', "age"])]
  y_train = train_df['age']

  X_test = test_df.loc[:, test_df.columns.difference(['Id', "sampling_rate", 'path', "age"])]
  y_test = test_df['age']


  # Exclude features for "mfcc" configuration
  excluded_features = [feature for feature in df_finale.columns if "mean_speed" in feature or "mean_acceleration" in feature or feature.startswith("acf") or
                       "std_speed" in feature or "std_acceleration" in feature or "mean_mel" in feature or "std_mel" in feature ]

  X_train_mfcc_mel = X_train.drop(columns=excluded_features, errors='ignore')
  X_test_mfcc_mel = X_test.drop(columns=excluded_features, errors='ignore')

  # Train model with original data
  best_model_name_original, best_rmse_original, best_model_original, rmse_scores_original = run_for_plot(X_train, X_test, y_train, y_test)
  print(f"Miglior modello (Original Data): {best_model_name_original}, RMSE: {best_rmse_original}")

  # Train model with excluded features
  best_model_name_mfcc_mel, best_rmse_mfcc_mel, best_model_mfcc_mel, rmse_scores_mfcc_mel = run_for_plot(X_train_mfcc_mel, X_test_mfcc_mel, y_train, y_test)
  print(f"Miglior modello (mfcc + mel): {best_model_name_mfcc_mel}, RMSE: {best_rmse_mfcc_mel}")

  return {
      'original': (best_model_original, X_train, train_df, test_df, best_rmse_original, rmse_scores_original),
      'mfcc': (best_model_mfcc_mel, X_train_mfcc_mel, train_df, test_df, best_rmse_mfcc_mel, rmse_scores_mfcc_mel)
  }

# %%
def obtain_comparison_RF_SVR(max_sample_cat_values):
  rmse_by_sample = {'SVR': [], 'Random Forest': []}


  for max_sample in max_sample_cat_values:
      print(f"Processing max_sample_cat: {max_sample}")
      try:
          best_model, train_model, train_df, test_df, best_rmse, rmse_scores,a,b,c = train(path_df_train, max_sample)
          rmse_by_sample['SVR'].append((max_sample, rmse_scores['Support Vector Regressor']))
          rmse_by_sample['Random Forest'].append((max_sample, rmse_scores['Random Forest']))
      except Exception as e:
          print(f"Error for max_sample_cat = {max_sample}: {e}")

  return rmse_by_sample
# Out:
# Processing max_sample_cat: 140
# <ipython-input-4-7d70bb6ac7c4>:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
# <ipython-input-4-7d70bb6ac7c4>:16: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
# Random Forest - RMSE: 10.211284619103047
# Support Vector Regressor - RMSE: 9.16538669409444
#
# Il miglior modello è Support Vector Regressor con RMSE = 9.16538669409444
# Miglior modello: Support Vector Regressor, RMSE: 9.16538669409444
# Processing max_sample_cat: 150
# <ipython-input-4-7d70bb6ac7c4>:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
# <ipython-input-4-7d70bb6ac7c4>:16: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
# Random Forest - RMSE: 10.124157858284613
# Support Vector Regressor - RMSE: 9.14841310628071
#
# Il miglior modello è Support Vector Regressor con RMSE = 9.14841310628071
# Miglior modello: Support Vector Regressor, RMSE: 9.14841310628071
# Processing max_sample_cat: 160
# <ipython-input-4-7d70bb6ac7c4>:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
# <ipython-input-4-7d70bb6ac7c4>:16: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
# Random Forest - RMSE: 10.12122096449976
# Support Vector Regressor - RMSE: 9.152345323588607
#
# Il miglior modello è Support Vector Regressor con RMSE = 9.152345323588607
# Miglior modello: Support Vector Regressor, RMSE: 9.152345323588607
# Processing max_sample_cat: 170
# <ipython-input-4-7d70bb6ac7c4>:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
# <ipython-input-4-7d70bb6ac7c4>:16: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
# Random Forest - RMSE: 10.036254751331391
# Support Vector Regressor - RMSE: 9.157585355898034
#
# Il miglior modello è Support Vector Regressor con RMSE = 9.157585355898034
# Miglior modello: Support Vector Regressor, RMSE: 9.157585355898034
# Processing max_sample_cat: 180
# <ipython-input-4-7d70bb6ac7c4>:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
# <ipython-input-4-7d70bb6ac7c4>:16: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
# Random Forest - RMSE: 9.868978709994206
# Support Vector Regressor - RMSE: 9.143738142483121
#
# Il miglior modello è Support Vector Regressor con RMSE = 9.143738142483121
# Miglior modello: Support Vector Regressor, RMSE: 9.143738142483121

# %%
def obtain_mffc_without_spectrogram_and_spectrogram(max_sample_cat_values):
  rmse_by_sample_feature = {'MFCC': [], 'MFCC + Spectrogram': []}
  for max_sample in max_sample_cat_values:
      print(f"Processing max_sample_cat: {max_sample}")
      try:
          # Perform training
          results = train_feature(path_df_train, max_sample)

          # Save RMSE for both configurations
          rmse_by_sample_feature['MFCC'].append((max_sample, results['mfcc'][4]))  # RMSE mfcc_mel
          rmse_by_sample_feature['MFCC + Spectrogram'].append((max_sample, results['original'][4]))  # RMSE original

      except Exception as e:
          print(f"Error for max_sample_cat = {max_sample}: {e}")
  return rmse_by_sample_feature
# Out:
# Processing max_sample_cat: 140
# <ipython-input-30-3fcc814496a1>:28: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
# <ipython-input-30-3fcc814496a1>:28: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
# Support Vector Regressor - RMSE: 9.176289540559253
#
# Il miglior modello è Support Vector Regressor con RMSE = 9.176289540559253
# Miglior modello (Original Data): Support Vector Regressor, RMSE: 9.176289540559253
# Support Vector Regressor - RMSE: 9.200756727803439
#
# Il miglior modello è Support Vector Regressor con RMSE = 9.200756727803439
# Miglior modello (mfcc + mel): Support Vector Regressor, RMSE: 9.200756727803439
# Processing max_sample_cat: 150
# <ipython-input-30-3fcc814496a1>:28: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
# <ipython-input-30-3fcc814496a1>:28: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
# Support Vector Regressor - RMSE: 9.15552806993754
#
# Il miglior modello è Support Vector Regressor con RMSE = 9.15552806993754
# Miglior modello (Original Data): Support Vector Regressor, RMSE: 9.15552806993754
# Support Vector Regressor - RMSE: 9.168018982399
#
# Il miglior modello è Support Vector Regressor con RMSE = 9.168018982399
# Miglior modello (mfcc + mel): Support Vector Regressor, RMSE: 9.168018982399
# Processing max_sample_cat: 160
# <ipython-input-30-3fcc814496a1>:28: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
# <ipython-input-30-3fcc814496a1>:28: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
# Support Vector Regressor - RMSE: 9.161751585019665
#
# Il miglior modello è Support Vector Regressor con RMSE = 9.161751585019665
# Miglior modello (Original Data): Support Vector Regressor, RMSE: 9.161751585019665
# Support Vector Regressor - RMSE: 9.1718011507973
#
# Il miglior modello è Support Vector Regressor con RMSE = 9.1718011507973
# Miglior modello (mfcc + mel): Support Vector Regressor, RMSE: 9.1718011507973
# Processing max_sample_cat: 170
# <ipython-input-30-3fcc814496a1>:28: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
# <ipython-input-30-3fcc814496a1>:28: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
# Support Vector Regressor - RMSE: 9.168984774095994
#
# Il miglior modello è Support Vector Regressor con RMSE = 9.168984774095994
# Miglior modello (Original Data): Support Vector Regressor, RMSE: 9.168984774095994
# Support Vector Regressor - RMSE: 9.19798763754292
#
# Il miglior modello è Support Vector Regressor con RMSE = 9.19798763754292
# Miglior modello (mfcc + mel): Support Vector Regressor, RMSE: 9.19798763754292
# Processing max_sample_cat: 180
# <ipython-input-30-3fcc814496a1>:28: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
# <ipython-input-30-3fcc814496a1>:28: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   train_df = train_df.groupby('age_group', group_keys=False).apply(limit_samples)
# Support Vector Regressor - RMSE: 9.157877149026424
#
# Il miglior modello è Support Vector Regressor con RMSE = 9.157877149026424
# Miglior modello (Original Data): Support Vector Regressor, RMSE: 9.157877149026424
# Support Vector Regressor - RMSE: 9.226352074095827
#
# Il miglior modello è Support Vector Regressor con RMSE = 9.226352074095827
# Miglior modello (mfcc + mel): Support Vector Regressor, RMSE: 9.226352074095827

# %% [markdown]
# ####PLOT INTERFACE

# %%
new_dict = rmse_by_sample.copy()  # Creare una copia del dizionario originale
if 'SVD' in rmse_by_sample:  # Verificare che 'SVD' esista nel dizionario originale
    new_dict['SVR'] = new_dict.pop('SVD')  # Rinominare la chiave
print(new_dict)
# Out:
# {'Random Forest': [(140, 10.211284619103047), (150, 10.124157858284613), (160, 10.12122096449976), (170, 10.036254751331391), (180, 9.868978709994206)], 'SVR': [(140, 9.16538669409444), (150, 9.14841310628071), (160, 9.152345323588607), (170, 9.157585355898034), (180, 9.143738142483121)]}

# %%
# List of max_sample_cat values to consider
max_sample_cat_values = range(140, 181, 10)

# %%
plot_rmse_by_sample_features(new_dict, "Max Samples per Category")

# %%
comparing_dic = obtain_mffc_without_spectrogram_and_spectrogram(max_sample_cat_values)
plot_rmse_by_sample_features(comparing_dic, "Max Samples per Category")
